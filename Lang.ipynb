# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
df = pd.read_csv("/home/bitbug/Documents/Shell/review_data.xlsx.csv")

# Clean column names
df.columns = df.columns.str.strip()

# ----------------------------
# 1. Basic Info
# ----------------------------
print("Shape:", df.shape)
print("\nColumns:", df.columns)
print("\nData Types:\n", df.dtypes)

# ----------------------------
# 2. Summary Statistics
# ----------------------------
print("\nSummary Statistics:\n", df.describe())

# ----------------------------
# 3. Check Missing Values
# ----------------------------
print("\nMissing Values:\n", df.isnull().sum())

# ----------------------------
# 4. Histograms (Numerical)
# ----------------------------
df.hist(figsize=(10, 8), bins=20)
plt.suptitle("Histograms of Numerical Features")
plt.show()

# ----------------------------
# 5. Boxplots (Outliers)
# ----------------------------
for col in df.select_dtypes(include=['int64', 'float64']).columns:
    plt.figure()
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# ----------------------------
# 6. Value Counts (Categorical)
# ----------------------------
for col in df.select_dtypes(include=['object']).columns:
    print(f"\nValue counts for {col}:\n")
    print(df[col].value_counts())

# ----------------------------
# 7. Count Plots (Categorical)
# ----------------------------
for col in df.select_dtypes(include=['object']).columns:
    plt.figure()
    sns.countplot(x=df[col])
    plt.title(f"Count Plot of {col}")
    plt.xticks(rotation=45)
    plt.show()
# Out:
# Shape: (504, 20)
#
# Columns: Index(['User country', 'Nr. reviews', 'Nr. hotel reviews', 'Helpful votes',
#        'Score', 'Period of stay', 'Traveler type', 'Swimming Pool',
#        'Exercise Room', 'Basketball Court', 'Yoga Classes', 'Club',
#        'Free Wifi', 'Hotel name', 'Hotel stars', 'Nr. rooms', 'User continent',
#        'Member years', 'Review month', 'Review weekday'],
#       dtype='str')
#
# Data Types:
#  User country           str
# Nr. reviews          int64
# Nr. hotel reviews    int64
# Helpful votes        int64
# Score                int64
# Period of stay         str
# Traveler type          str
# Swimming Pool          str
# Exercise Room          str
# Basketball Court       str
# Yoga Classes           str
# Club                   str
# Free Wifi              str
# Hotel name             str
# Hotel stars            str
# Nr. rooms            int64
# User continent         str
# Member years         int64
# Review month           str
# Review weekday         str
# dtype: object
#
# Summary Statistics:
#         Nr. reviews  Nr. hotel reviews  Helpful votes       Score    Nr. rooms  \
# count   504.000000         504.000000     504.000000  504.000000   504.000000
# mean     48.130952          16.023810      31.751984    4.123016  2196.380952
# std      74.996426          23.957953      48.520783    1.007302  1285.476807
# min       1.000000           0.000000       0.000000    1.000000   188.000000
# 25%      12.000000           5.000000       8.000000    4.000000   826.000000
# 50%      23.500000           9.000000      16.000000    4.000000  2700.000000
# 75%      54.250000          18.000000      35.000000    5.000000  3025.000000
# max     775.000000         263.000000     365.000000    5.000000  4027.000000
#
#        Member years
# count    504.000000
# mean       0.767857
# std       80.692897
# min    -1806.000000
# 25%        2.000000
# 50%        4.000000
# 75%        6.000000
# max       13.000000
#
# Missing Values:
#  User country         0
# Nr. reviews          0
# Nr. hotel reviews    0
# Helpful votes        0
# Score                0
# Period of stay       0
# Traveler type        0
# Swimming Pool        0
# Exercise Room        0
# Basketball Court     0
# Yoga Classes         0
# Club                 0
# Free Wifi            0
# Hotel name           0
# Hotel stars          0
# Nr. rooms            0
# User continent       0
# Member years         0
# Review month         0
# Review weekday       0
# dtype: int64
# /tmp/ipykernel_11279/702609171.py:47: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   for col in df.select_dtypes(include=['object']).columns:
# /tmp/ipykernel_11279/702609171.py:54: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   for col in df.select_dtypes(include=['object']).columns:
# Value counts for User country:
#
# User country
# USA                     217
# UK                       72
# Canada                   65
# Australia                36
# Ireland                  13
# India                    11
# Mexico                    8
# Germany                   7
# New Zeland                5
# Egypt                     5
# Brazil                    5
# Netherlands               4
# Singapore                 4
# Finland                   3
# Malaysia                  3
# Thailand                  3
# Israel                    3
# Norway                    3
# Hawaii                    3
# Scotland                  2
# United Arab Emirates      2
# Switzerland               2
# Spain                     2
# Costa Rica                2
# Kenya                     1
# Jordan                    1
# Syria                     1
# South Africa              1
# Swiss                     1
# Hungary                   1
# China                     1
# Greece                    1
# Croatia                   1
# Phillippines              1
# India                     1
# Belgium                   1
# Puerto Rico               1
# France                    1
# Iran                      1
# Saudi Arabia              1
# Honduras                  1
# Denmark                   1
# Taiwan                    1
# Kuwait                    1
# Czech Republic            1
# Japan                     1
# Korea                     1
# Italy                     1
# Name: count, dtype: int64
#
# Value counts for Period of stay:
#
# Period of stay
# Mar-May    128
# Jun-Aug    126
# Sep-Nov    126
# Dec-Feb    124
# Name: count, dtype: int64
#
# Value counts for Traveler type:
#
# Traveler type
# Couples     214
# Families    110
# Friends      82
# Business     74
# Solo         24
# Name: count, dtype: int64
#
# Value counts for Swimming Pool:
#
# Swimming Pool
# YES    480
# NO      24
# Name: count, dtype: int64
#
# Value counts for Exercise Room:
#
# Exercise Room
# YES    480
# NO      24
# Name: count, dtype: int64
#
# Value counts for Basketball Court:
#
# Basketball Court
# NO     384
# YES    120
# Name: count, dtype: int64
#
# Value counts for Yoga Classes:
#
# Yoga Classes
# YES    384
# NO     120
# Name: count, dtype: int64
#
# Value counts for Club:
#
# Club
# YES    456
# NO      48
# Name: count, dtype: int64
#
# Value counts for Free Wifi:
#
# Free Wifi
# YES    480
# NO      24
# Name: count, dtype: int64
#
# Value counts for Hotel name:
#
# Hotel name
# Circus Circus Hotel & Casino Las Vegas                 24
# Excalibur Hotel & Casino                               24
# Monte Carlo Resort&Casino                              24
# Treasure Island- TI Hotel & Casino                     24
# Tropicana Las Vegas - A Double Tree by Hilton Hotel    24
# Caesars Palace                                         24
# The Cosmopolitan Las Vegas                             24
# The Palazzo Resort Hotel Casino                        24
# Wynn Las Vegas                                         24
# Trump International Hotel Las Vegas                    24
# The Cromwell                                           24
# Encore at wynn Las Vegas                               24
# Hilton Grand Vacations on the Boulevard                24
# Marriott's Grand Chateau                               24
# Tuscany Las Vegas Suites & Casino                      24
# Hilton Grand Vacations at the Flamingo                 24
# Wyndham Grand Desert                                   24
# The Venetian Las Vegas Hotel                           24
# Bellagio Las Vegas                                     24
# Paris Las Vegas                                        24
# The Westin las Vegas Hotel Casino & Spa                24
# Name: count, dtype: int64
#
# Value counts for Hotel stars:
#
# Hotel stars
# 5      192
# 4      120
# 3       96
# 3,5     72
# 4,5     24
# Name: count, dtype: int64
#
# Value counts for User continent:
#
# User continent
# North America    295
# Europe           118
# Oceania           41
# Asia              36
# Africa             7
# South America      7
# Name: count, dtype: int64
#
# Value counts for Review month:
#
# Review month
# January      42
# February     42
# March        42
# April        42
# May          42
# June         42
# July         42
# August       42
# September    42
# October      42
# November     42
# December     42
# Name: count, dtype: int64
#
# Value counts for Review weekday:
#
# Review weekday
# Wednesday    85
# Tuesday      80
# Sunday       77
# Monday       74
# Friday       65
# Thursday     62
# Saturday     61
# Name: count, dtype: int64
