# %% [markdown]
# # Pandas

# %%
pip install pandas numpy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Series

# %% [markdown]
# Creation

# %% [raw]
# Tata        100
# Birla       200
# Wipro       300
# ITC         400

# %%
mylist1 = [100,200,300,400]
indexlist = ['Tata', 'Birla', 'Wipro', 'ITC']

# %%
ps1 = pd.Series(mylist1)
print(type(ps1))
print(ps1)
print(ps1[2])
# Out:
# <class 'pandas.core.series.Series'>
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64
# 300

# %%
print(ps1.index)
print(ps1.shape)
print(ps1.ndim)
print(ps1.size)
print(ps1.dtype)
print(ps1.values)
print(type(ps1.values))
# Out:
# RangeIndex(start=0, stop=4, step=1)
# (4,)
# 1
# 4
# int64
# [100 200 300 400]
# <class 'numpy.ndarray'>

# %%
ps2 = pd.Series(mylist1, index=indexlist)
print(ps2)
print(ps2.index)
print(ps2['Wipro'])
# Out:
# Tata     100
# Birla    200
# Wipro    300
# ITC      400
# dtype: int64
# Index(['Tata', 'Birla', 'Wipro', 'ITC'], dtype='object')
# 300

# %%
r = ps2['Tata']
print(type(r))
# Out:
# <class 'numpy.int64'>

# %%
ps2 = pd.Series(mylist1, index=indexlist, dtype=np.int32)
print(ps2)
# Out:
# Tata     100
# Birla    200
# Wipro    300
# ITC      400
# dtype: int32

# %%
ps2.dtype
# Out:
# dtype('int32')

# %%
np.random.seed(23)

n10 = np.random.randint(low=10, high=100, size=10)
n10
# Out:
# array([93, 50, 83, 64, 41, 86, 49, 35, 61, 16])

# %%
ps3 = pd.Series(n10)
ps3
# Out:
# 0    93
# 1    50
# 2    83
# 3    64
# 4    41
# 5    86
# 6    49
# 7    35
# 8    61
# 9    16
# dtype: int32

# %%
ps4 = pd.Series(n10, index=list('abcdefghij'))
ps4
# Out:
# a    93
# b    50
# c    83
# d    64
# e    41
# f    86
# g    49
# h    35
# i    61
# j    16
# dtype: int32

# %%
ps5 = pd.Series(n10, index=list('abcdefghi'))  # Error
ps5

# %% [raw]
# Tata        100
# Birla       200
# Wipro       300
# ITC         400

# %%
md1 = {'Tata':100, 'Birla':200, 'Wipro':300, 999:400}

ps6 = pd.Series(md1)
ps6
# Out:
# Tata     100
# Birla    200
# Wipro    300
# 999      400
# dtype: int64

# %%
ps6.index
# Out:
# Index(['Tata', 'Birla', 'Wipro', 999], dtype='object')

# %%
ps6[999]
# Out:
# 400

# %%
print(type(ps6.index))
# Out:
# <class 'pandas.core.indexes.base.Index'>

# %%
print(type(ps6.index[0]))
# Out:
# <class 'str'>

# %%
print(type(ps6.index[-1]))
# Out:
# <class 'int'>

# %% [markdown]
# # Accessing a  Series

# %%
np.random.seed(23)
n10 = np.random.randint(low=10, high=100, size=10)
ps7 = pd.Series(n10, index=list('abcdefghij'))
print(ps7.index)
ps7
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'], dtype='object')
# a    93
# b    50
# c    83
# d    64
# e    41
# f    86
# g    49
# h    35
# i    61
# j    16
# dtype: int32

# %%
ps7[0]
# Out:
# C:\Users\Edunet Foundation\AppData\Local\Temp\ipykernel_16100\2454248703.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ps7[0]
# 93

# %%
ps7['a']
# Out:
# 93

# %%
ps7[2:7]  ##in numerical slice endpoint = False
# Out:
# c    83
# d    64
# e    41
# f    86
# g    49
# dtype: int32

# %%
ps7['i':'c']  #  in labelled slice, endpoint=True
# Out:
# Series([], dtype: int32)

# %%
ps7['a']
# Out:
# 93

# %%
type(ps7['a'])
# Out:
# numpy.int32

# %%
type(ps7['b'])

# %%
ps7
# Out:
# a    93
# b    50
# c    83
# d    64
# e    41
# f    86
# g    49
# h    35
# i    61
# j    16
# dtype: int32

# %%
ps7[ [0,1,-2,-1]  ]
# Out:
# C:\Users\Edunet Foundation\AppData\Local\Temp\ipykernel_16100\2411164769.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ps7[ [0,1,-2,-1]  ]
# a    93
# b    50
# i    61
# j    16
# dtype: int32

# %%
ps7[ ['a','b','i'] ]
# Out:
# a    93
# b    50
# i    61
# dtype: int32

# %%
ps7
# Out:
# a    93
# b    50
# c    83
# d    64
# e    41
# f    86
# g    49
# h    35
# i    61
# j    16
# dtype: int32

# %%
mask = ps7 > 50
mask
# Out:
# a     True
# b    False
# c     True
# d     True
# e    False
# f     True
# g    False
# h    False
# i     True
# j    False
# dtype: bool

# %%
ps7[mask]
# Out:
# a    93
# c    83
# d    64
# f    86
# i    61
# dtype: int32

# %%
ps7[ps7>50]
# Out:
# a    93
# c    83
# d    64
# f    86
# i    61
# dtype: int32

# %% [markdown]
# # Data Frame

# %% [raw]
#        Vol  Rev  HQ
# Tata   100  75   'Mum'
# Birla  200  175  'Kol'
# Wipro  300  250  'Blr'
# ITC    400  450  'Mum'
# HCL    500  550  'NCR

# %%
mylist53 = [
    [100,75, 'Mum'],
    [200, 175, 'Kol'],
    [300, 250, 'Blr'],
    [400,450, 'Mum'],
    [500,550,'NCR']
]
row_index_list = ['Tata', 'Birla','Wipro','ITC','HCL']
col_index_list = ['Vol', 'Rev','HQ']

# %%
df1 = pd.DataFrame(mylist53)
print(type(df1))
print(df1)
print(df1.index)
print(df1.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      0    1    2
# 0  100   75  Mum
# 1  200  175  Kol
# 2  300  250  Blr
# 3  400  450  Mum
# 4  500  550  NCR
# RangeIndex(start=0, stop=5, step=1)
# RangeIndex(start=0, stop=3, step=1)

# %%
df1 = pd.DataFrame(mylist53, index=row_index_list, columns=col_index_list)
print(type(df1))
print(df1)
print(df1.index)
print(df1.columns)
print(df1.values)
print(type(df1.values))
# Out:
# <class 'pandas.core.frame.DataFrame'>
#        Vol  Rev   HQ
# Tata   100   75  Mum
# Birla  200  175  Kol
# Wipro  300  250  Blr
# ITC    400  450  Mum
# HCL    500  550  NCR
# Index(['Tata', 'Birla', 'Wipro', 'ITC', 'HCL'], dtype='object')
# Index(['Vol', 'Rev', 'HQ'], dtype='object')
# [[100 75 'Mum']
#  [200 175 'Kol']
#  [300 250 'Blr']
#  [400 450 'Mum']
#  [500 550 'NCR']]
# <class 'numpy.ndarray'>

# %% [raw]
#        Vol  Rev  HQ
# Tata   100  75   'Mum'
# Birla  200  175  'Kol'
# Wipro  300  250  'Blr'
# ITC    400  450  'Mum'
# HCL    500  550  'NCR

# %%
md1 = {'Vol':[100,200,300,400,500],  'Rev':[75,175,250,450,550], 
       'HQ':['Mum','Kol','Blr','Mum','NCR']}

# %%
df2 = pd.DataFrame(md1, index=row_index_list)
df2
# Out:
#        Vol  Rev   HQ
# Tata   100   75  Mum
# Birla  200  175  Kol
# Wipro  300  250  Blr
# ITC    400  450  Mum
# HCL    500  550  NCR

# %%
col_index_list1 = ['Vol1', 'Rev1','HQ']
df3 = pd.DataFrame(md1, index=row_index_list,columns=col_index_list1)
df3
# Out:
#       Vol1 Rev1   HQ
# Tata   NaN  NaN  Mum
# Birla  NaN  NaN  Kol
# Wipro  NaN  NaN  Blr
# ITC    NaN  NaN  Mum
# HCL    NaN  NaN  NCR

# %%
# Data Frame Access

# %%
import pandas as pd
import numpy as np
df1 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds1.csv')
df1
# Out:
#                      Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Kolkata_FMCG         925  874.40  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles          931  863.50  605    Pub    1935  NCR    0    NCRL
# Bangalore_Systems    900  881.60  650    Gov    1361  Blr    0    BSYS
# Chennai_Chemicals    966  863.20  608    Pub    1656  Che    1    CHEM
# Indi_Services        992  733.00  633    Gov   13023  NCR    0    INDI
# Chennai_Shipping     899  821.00  899    Pub     899  Che    1    SHIP
# Eastern_Estates      945  834.23  789   Prvt    1873  Kol    1    EEST
# Central_Services     934  824.00  689    Gov    1573  NCR    1    CSRV
# Deccan_Sporting      931  839.80  615   Prvt     154  Hyd    1    SPRT
# Bangalore_Breweries  966  875.00  674   Prvt     119  Blr    1    BREW
# Bombay_Finance       954  917.00  665    Pub    1443  Mum    0    BFIN
# NCR_Infra            921  843.50  615   Prvt    1635  NCR    0    NCIN
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 12 entries, Kolkata_FMCG to NCR_Infra
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Vol         11 non-null     float64
#  1   Rev         12 non-null     float64
#  2   Exp         12 non-null     int64
#  3   Sector      12 non-null     str
#  4   EmpCnt      12 non-null     int64
#  5   HQ          12 non-null     str
#  6   MNC         12 non-null     int64
#  7   StockID     12 non-null     str
#  8   GST         12 non-null     str
#  9   Start Date  12 non-null     str
#  10  Taxpaid     12 non-null     str
# dtypes: float64(2), int64(3), str(6)
# memory usage: 1.4+ KB

# %%
df1.describe()
# Out:
#               Vol         Rev         Exp        EmpCnt        MNC
# count   12.000000   12.000000   12.000000     12.000000  12.000000
# mean   938.666667  847.519167  676.500000   2254.166667   0.500000
# std     27.503168   45.318608   86.561066   3443.674751   0.522233
# min    899.000000  733.000000  605.000000    119.000000   0.000000
# 25%    924.000000  831.672500  615.000000   1245.500000   0.000000
# 50%    932.500000  853.350000  657.500000   1508.000000   0.500000
# 75%    957.000000  874.550000  679.250000   1710.250000   1.000000
# max    992.000000  917.000000  899.000000  13023.000000   1.000000

# %%
df1.iloc[0,0] = np.nan
df1
# Out:
#                        Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Kolkata_FMCG           NaN  874.40  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles          931.0  863.50  605    Pub    1935  NCR    0    NCRL
# Bangalore_Systems    900.0  881.60  650    Gov    1361  Blr    0    BSYS
# Chennai_Chemicals    966.0  863.20  608    Pub    1656  Che    1    CHEM
# Indi_Services        992.0  733.00  633    Gov   13023  NCR    0    INDI
# Chennai_Shipping     899.0  821.00  899    Pub     899  Che    1    SHIP
# Eastern_Estates      945.0  834.23  789   Prvt    1873  Kol    1    EEST
# Central_Services     934.0  824.00  689    Gov    1573  NCR    1    CSRV
# Deccan_Sporting      931.0  839.80  615   Prvt     154  Hyd    1    SPRT
# Bangalore_Breweries  966.0  875.00  674   Prvt     119  Blr    1    BREW
# Bombay_Finance       954.0  917.00  665    Pub    1443  Mum    0    BFIN
# NCR_Infra            921.0  843.50  615   Prvt    1635  NCR    0    NCIN
#
# ...

# %%
df1.isnull()
# Out:
#                        Vol    Rev    Exp  Sector  EmpCnt     HQ    MNC  \
# Kolkata_FMCG          True  False  False   False   False  False  False
# NCR_Leagles          False  False  False   False   False  False  False
# Bangalore_Systems    False  False  False   False   False  False  False
# Chennai_Chemicals    False  False  False   False   False  False  False
# Indi_Services        False  False  False   False   False  False  False
# Chennai_Shipping     False  False  False   False   False  False  False
# Eastern_Estates      False  False  False   False   False  False  False
# Central_Services     False  False  False   False   False  False  False
# Deccan_Sporting      False  False  False   False   False  False  False
# Bangalore_Breweries  False  False  False   False   False  False  False
# Bombay_Finance       False  False  False   False   False  False  False
# NCR_Infra            False  False  False   False   False  False  False
#
# ...

# %%
df1.isnull().sum()
# Out:
# Vol           1
# Rev           0
# Exp           0
# Sector        0
# EmpCnt        0
# HQ            0
# MNC           0
# StockID       0
# GST           0
# Start Date    0
# Taxpaid       0
# dtype: int64

# %%
df1.isnull().sum().sum()
# Out:
# np.int64(1)

# %%
df1['Vol']
# Out:
# Kolkata_FMCG             NaN
# NCR_Leagles            931.0
# Bangalore_Systems      900.0
# Chennai_Chemicals      966.0
# Indi_Services          992.0
# Chennai_Shipping       899.0
# Eastern_Estates        945.0
# Central_Services       934.0
# Deccan_Sporting        931.0
# Bangalore_Breweries    966.0
# Bombay_Finance         954.0
# NCR_Infra              921.0
# Name: Vol, dtype: float64

# %%
df1[   ['Rev','HQ','Vol']   ]
# Out:
#                         Rev   HQ    Vol
# Kolkata_FMCG         874.40  Kol    NaN
# NCR_Leagles          863.50  NCR  931.0
# Bangalore_Systems    881.60  Blr  900.0
# Chennai_Chemicals    863.20  Che  966.0
# Indi_Services        733.00  NCR  992.0
# Chennai_Shipping     821.00  Che  899.0
# Eastern_Estates      834.23  Kol  945.0
# Central_Services     824.00  NCR  934.0
# Deccan_Sporting      839.80  Hyd  931.0
# Bangalore_Breweries  875.00  Blr  966.0
# Bombay_Finance       917.00  Mum  954.0
# NCR_Infra            843.50  NCR  921.0

# %%
df1.index
# Out:
# Index(['Kolkata_FMCG', 'NCR_Leagles', 'Bangalore_Systems', 'Chennai_Chemicals',
#        'Indi_Services', 'Chennai_Shipping', 'Eastern_Estates',
#        'Central_Services', 'Deccan_Sporting', 'Bangalore_Breweries',
#        'Bombay_Finance'],
#       dtype='object')

# %%
df1['NCR_Leagles': 'Bombay_Finance']
# Out:
#                        Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# NCR_Leagles          931.0  863.50  605    Pub    1935  NCR    0    NCRL
# Bangalore_Systems    900.0  881.60  650    Gov    1361  Blr    0    BSYS
# Chennai_Chemicals    966.0  863.20  608    Pub    1656  Che    1    CHEM
# Indi_Services        992.0  733.00  633    Gov   13023  NCR    0    INDI
# Chennai_Shipping     899.0  821.00  899    Pub     899  Che    1    SHIP
# Eastern_Estates      945.0  834.23  789   Prvt    1873  Kol    1    EEST
# Central_Services     934.0  824.00  689    Gov    1573  NCR    1    CSRV
# Deccan_Sporting      931.0  839.80  615   Prvt     154  Hyd    1    SPRT
# Bangalore_Breweries  966.0  875.00  674   Prvt     119  Blr    1    BREW
# Bombay_Finance       954.0  917.00  665    Pub    1443  Mum    0    BFIN
#
#                           GST Start Date Taxpaid
# NCR_Leagles          Services   Feb 1960  38.78$
# Bangalore_Systems    Services   Apr 1950  34.74$
# ...

# %%
df1['NCR_Leagles': 'NCR_Leagles']
# Out:
#                Vol    Rev  Exp Sector  EmpCnt   HQ  MNC StockID       GST  \
# NCR_Leagles  931.0  863.5  605    Pub    1935  NCR    0    NCRL  Services
#
#             Start Date Taxpaid
# NCR_Leagles   Feb 1960  38.78$

# %%
df1.Exp
# Out:
# Kolkata_FMCG           676
# NCR_Leagles            605
# Bangalore_Systems      650
# Chennai_Chemicals      608
# Indi_Services          633
# Chennai_Shipping       899
# Eastern_Estates        789
# Central_Services       689
# Deccan_Sporting        615
# Bangalore_Breweries    674
# Bombay_Finance         665
# NCR_Infra              615
# Name: Exp, dtype: int64

# %%
df1['EmpCnt']['Chennai_Shipping']
# Out:
# np.int64(899)

# %%
df1['Chennai_Shipping':'Chennai_Shipping']
# Out:
#                     Vol    Rev  Exp Sector  EmpCnt   HQ  MNC StockID    GST  \
# Chennai_Shipping  899.0  821.0  899    Pub     899  Che    1    SHIP  Goods
#
#                  Start Date Taxpaid
# Chennai_Shipping   Nov 1930       0

# %%
df1['Chennai_Shipping':'Chennai_Shipping']['EmpCnt']
# Out:
# Chennai_Shipping    899
# Name: EmpCnt, dtype: int64

# %%
df1['Chennai_Shipping':'Chennai_Shipping']['EmpCnt'].values[0]
# Out:
# np.int64(899)

# %%
df1['Chennai_Shipping':'Chennai_Shipping'][  ['EmpCnt', 'Exp', 'Vol'] ]
# Out:
#                   EmpCnt  Exp    Vol
# Chennai_Shipping     899  899  899.0

# %%
df1.iloc[0]
# Out:
# Vol                NaN
# Rev              874.4
# Exp                676
# Sector             Pub
# EmpCnt            1379
# HQ                 Kol
# MNC                  0
# StockID           KFMC
# GST              Goods
# Start Date    Jan 1920
# Taxpaid         29.76$
# Name: Kolkata_FMCG, dtype: object

# %%
df1.iloc[0,1]
# Out:
# np.float64(874.4)

# %%
df1.iloc[3:7]
# Out:
#                      Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Chennai_Chemicals  966.0  863.20  608    Pub    1656  Che    1    CHEM
# Indi_Services      992.0  733.00  633    Gov   13023  NCR    0    INDI
# Chennai_Shipping   899.0  821.00  899    Pub     899  Che    1    SHIP
# Eastern_Estates    945.0  834.23  789   Prvt    1873  Kol    1    EEST
#
#                         GST Start Date Taxpaid
# Chennai_Chemicals     Goods   Aug 1928  38.28$
# Indi_Services      Services   Mar 1920     15$
# Chennai_Shipping      Goods   Nov 1930       0
# Eastern_Estates       Goods   Jan 1994   6.78$

# %%
df1.iloc[3:7, 4:7]
# Out:
#                    EmpCnt   HQ  MNC
# Chennai_Chemicals    1656  Che    1
# Indi_Services       13023  NCR    0
# Chennai_Shipping      899  Che    1
# Eastern_Estates      1873  Kol    1

# %%
df1.columns[4:7]
# Out:
# Index(['EmpCnt', 'HQ', 'MNC'], dtype='str')

# %%
df1.index[3:7]
# Out:
# Index(['Chennai_Chemicals', 'Indi_Services', 'Chennai_Shipping',
#        'Eastern_Estates'],
#       dtype='str')

# %%
df1.iloc[ [0,1,-1,-2,-3] ]
# Out:
#                        Vol    Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Kolkata_FMCG           NaN  874.4  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles          931.0  863.5  605    Pub    1935  NCR    0    NCRL
# NCR_Infra            921.0  843.5  615   Prvt    1635  NCR    0    NCIN
# Bombay_Finance       954.0  917.0  665    Pub    1443  Mum    0    BFIN
# Bangalore_Breweries  966.0  875.0  674   Prvt     119  Blr    1    BREW
#
#                           GST Start Date Taxpaid
# Kolkata_FMCG            Goods   Jan 1920  29.76$
# NCR_Leagles          Services   Feb 1960  38.78$
# NCR_Infra            Services   Feb 1920  34.27$
# Bombay_Finance       Services   Apr 1925   37.8$
# Bangalore_Breweries     Goods   Oct 1971  19.65$

# %%
df1.iloc[ [0,1,-1,-2,-3] ,   [0,-1,-2]   ]
# Out:
#                        Vol Taxpaid Start Date
# Kolkata_FMCG           NaN  29.76$   Jan 1920
# NCR_Leagles          931.0  38.78$   Feb 1960
# NCR_Infra            921.0  34.27$   Feb 1920
# Bombay_Finance       954.0   37.8$   Apr 1925
# Bangalore_Breweries  966.0  19.65$   Oct 1971

# %%
df1.index
# Out:
# Index(['Kolkata_FMCG', 'NCR_Leagles', 'Bangalore_Systems', 'Chennai_Chemicals',
#        'Indi_Services', 'Chennai_Shipping', 'Eastern_Estates',
#        'Central_Services', 'Deccan_Sporting', 'Bangalore_Breweries',
#        'Bombay_Finance', 'NCR_Infra'],
#       dtype='str')

# %%
df1.columns
# Out:
# Index(['Vol', 'Rev', 'Exp', 'Sector', 'EmpCnt', 'HQ', 'MNC', 'StockID', 'GST',
#        'Start Date', 'Taxpaid'],
#       dtype='str')

# %%
df1.loc['NCR_Leagles']
# Out:
# Vol              931.0
# Rev              863.5
# Exp                605
# Sector             Pub
# EmpCnt            1935
# HQ                 NCR
# MNC                  0
# StockID           NCRL
# GST           Services
# Start Date    Feb 1960
# Taxpaid         38.78$
# Name: NCR_Leagles, dtype: object

# %%
df1.loc['NCR_Leagles', 'EmpCnt']
# Out:
# np.int64(1935)

# %%
df1.loc['NCR_Leagles': 'Chennai_Chemicals':2]
# Out:
#                      Vol    Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# NCR_Leagles        931.0  863.5  605    Pub    1935  NCR    0    NCRL
# Chennai_Chemicals  966.0  863.2  608    Pub    1656  Che    1    CHEM
#
#                         GST Start Date Taxpaid
# NCR_Leagles        Services   Feb 1960  38.78$
# Chennai_Chemicals     Goods   Aug 1928  38.28$

# %%
df1.loc['NCR_Leagles': 'Chennai_Chemicals':2,  'Exp':'GST']
# Out:
#                    Exp Sector  EmpCnt   HQ  MNC StockID       GST
# NCR_Leagles        605    Pub    1935  NCR    0    NCRL  Services
# Chennai_Chemicals  608    Pub    1656  Che    1    CHEM     Goods

# %%
df1.loc[['NCR_Leagles','Chennai_Chemicals','Bombay_Finance']]
# Out:
#                      Vol    Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# NCR_Leagles        931.0  863.5  605    Pub    1935  NCR    0    NCRL
# Chennai_Chemicals  966.0  863.2  608    Pub    1656  Che    1    CHEM
# Bombay_Finance     954.0  917.0  665    Pub    1443  Mum    0    BFIN
#
#                         GST Start Date Taxpaid
# NCR_Leagles        Services   Feb 1960  38.78$
# Chennai_Chemicals     Goods   Aug 1928  38.28$
# Bombay_Finance     Services   Apr 1925   37.8$

# %%
df1
# Out:
#                        Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Kolkata_FMCG           NaN  874.40  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles          931.0  863.50  605    Pub    1935  NCR    0    NCRL
# Bangalore_Systems    900.0  881.60  650    Gov    1361  Blr    0    BSYS
# Chennai_Chemicals    966.0  863.20  608    Pub    1656  Che    1    CHEM
# Indi_Services        992.0  733.00  633    Gov   13023  NCR    0    INDI
# Chennai_Shipping     899.0  821.00  899    Pub     899  Che    1    SHIP
# Eastern_Estates      945.0  834.23  789   Prvt    1873  Kol    1    EEST
# Central_Services     934.0  824.00  689    Gov    1573  NCR    1    CSRV
# Deccan_Sporting      931.0  839.80  615   Prvt     154  Hyd    1    SPRT
# Bangalore_Breweries  966.0  875.00  674   Prvt     119  Blr    1    BREW
# Bombay_Finance       954.0  917.00  665    Pub    1443  Mum    0    BFIN
# NCR_Infra            921.0  843.50  615   Prvt    1635  NCR    0    NCIN
#
# ...

# %%
df1.loc['Bombay_Sporting':'Bangalore_Breweries', ['Exp','GST','Sector'] ]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df1.loc['Bombay_Sporting':'Bangalore_Breweries', ['Exp','GST','Sector'] ]
#
# File ~/Documents/Shell/venv/lib/python3.12/site-packages/pandas/core/indexing.py:1200, in _LocationIndexer.__getitem__(self, key)
#    1198     if self._is_scalar_access(key):
#    1199         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1200     return self._getitem_tuple(key)
#    1201 else:
#    1202     # we by definition only have the 0th axis
#    1203     axis = self.axis or 0
#
# File ~/Documents/Shell/venv/lib/python3.12/site-packages/pandas/core/indexing.py:1386, in _LocIndexer._getitem_tuple(self, tup)
#    1384 with suppress(IndexingError):
#    1385     tup = self._expand_ellipsis(tup)
# -> 1386     return self._getitem_lowerdim(tup)
#    1388 # no multi-index, so validate all of the indexers
# ...

# %% [markdown]
# Conditional Access

# %%
df1
# Out:
#                        Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Kolkata_FMCG           NaN  874.40  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles          931.0  863.50  605    Pub    1935  NCR    0    NCRL
# Bangalore_Systems    900.0  881.60  650    Gov    1361  Blr    0    BSYS
# Chennai_Chemicals    966.0  863.20  608    Pub    1656  Che    1    CHEM
# Indi_Services        992.0  733.00  633    Gov   13023  NCR    0    INDI
# Chennai_Shipping     899.0  821.00  899    Pub     899  Che    1    SHIP
# Eastern_Estates      945.0  834.23  789   Prvt    1873  Kol    1    EEST
# Central_Services     934.0  824.00  689    Gov    1573  NCR    1    CSRV
# Deccan_Sporting      931.0  839.80  615   Prvt     154  Hyd    1    SPRT
# Bangalore_Breweries  966.0  875.00  674   Prvt     119  Blr    1    BREW
# Bombay_Finance       954.0  917.00  665    Pub    1443  Mum    0    BFIN
# NCR_Infra            921.0  843.50  615   Prvt    1635  NCR    0    NCIN
#
# ...

# %%
mask = df1.Sector == 'Pub'
mask
# Out:
# Kolkata_FMCG            True
# NCR_Leagles             True
# Bangalore_Systems      False
# Chennai_Chemicals       True
# Indi_Services          False
# Chennai_Shipping        True
# Eastern_Estates        False
# Central_Services       False
# Deccan_Sporting        False
# Bangalore_Breweries    False
# Bombay_Finance          True
# NCR_Infra              False
# Name: Sector, dtype: bool

# %%
df1[mask]
# Out:
#                      Vol    Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Kolkata_FMCG         NaN  874.4  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles        931.0  863.5  605    Pub    1935  NCR    0    NCRL
# Chennai_Chemicals  966.0  863.2  608    Pub    1656  Che    1    CHEM
# Chennai_Shipping   899.0  821.0  899    Pub     899  Che    1    SHIP
# Bombay_Finance     954.0  917.0  665    Pub    1443  Mum    0    BFIN
#
#                         GST Start Date Taxpaid
# Kolkata_FMCG          Goods   Jan 1920  29.76$
# NCR_Leagles        Services   Feb 1960  38.78$
# Chennai_Chemicals     Goods   Aug 1928  38.28$
# Chennai_Shipping      Goods   Nov 1930       0
# Bombay_Finance     Services   Apr 1925   37.8$

# %%
df1[df1.Sector == 'Pub']
# Out:
#                      Vol    Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Kolkata_FMCG         NaN  874.4  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles        931.0  863.5  605    Pub    1935  NCR    0    NCRL
# Chennai_Chemicals  966.0  863.2  608    Pub    1656  Che    1    CHEM
# Chennai_Shipping   899.0  821.0  899    Pub     899  Che    1    SHIP
# Bombay_Finance     954.0  917.0  665    Pub    1443  Mum    0    BFIN
#
#                         GST Start Date Taxpaid
# Kolkata_FMCG          Goods   Jan 1920  29.76$
# NCR_Leagles        Services   Feb 1960  38.78$
# Chennai_Chemicals     Goods   Aug 1928  38.28$
# Chennai_Shipping      Goods   Nov 1930       0
# Bombay_Finance     Services   Apr 1925   37.8$

# %%
df1['Sector'].unique()
# Out:
# <StringArray>
# ['Pub', 'Gov', 'Prvt']
# Length: 3, dtype: str

# %%
df1['GST'].unique()
# Out:
# <StringArray>
# ['Goods', 'Services']
# Length: 2, dtype: str

# %%
df1[ (df1.Sector == 'Pub') & (df1.GST == 'Services')]
# Out:
#                   Vol    Rev  Exp Sector  EmpCnt   HQ  MNC StockID       GST  \
# NCR_Leagles     931.0  863.5  605    Pub    1935  NCR    0    NCRL  Services
# Bombay_Finance  954.0  917.0  665    Pub    1443  Mum    0    BFIN  Services
#
#                Start Date Taxpaid
# NCR_Leagles      Feb 1960  38.78$
# Bombay_Finance   Apr 1925   37.8$

# %%
df1["HQ"].unique()
# Out:
# <StringArray>
# ['Kol', 'NCR', 'Blr', 'Che', 'Hyd', 'Mum']
# Length: 6, dtype: str

# %%
df1
# Out:
#                        Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Kolkata_FMCG           NaN  874.40  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles          931.0  863.50  605    Pub    1935  NCR    0    NCRL
# Bangalore_Systems    900.0  881.60  650    Gov    1361  Blr    0    BSYS
# Chennai_Chemicals    966.0  863.20  608    Pub    1656  Che    1    CHEM
# Indi_Services        992.0  733.00  633    Gov   13023  NCR    0    INDI
# Chennai_Shipping     899.0  821.00  899    Pub     899  Che    1    SHIP
# Eastern_Estates      945.0  834.23  789   Prvt    1873  Kol    1    EEST
# Central_Services     934.0  824.00  689    Gov    1573  NCR    1    CSRV
# Deccan_Sporting      931.0  839.80  615   Prvt     154  Hyd    1    SPRT
# Bangalore_Breweries  966.0  875.00  674   Prvt     119  Blr    1    BREW
# Bombay_Finance       954.0  917.00  665    Pub    1443  Mum    0    BFIN
# NCR_Infra            921.0  843.50  615   Prvt    1635  NCR    0    NCIN
#
# ...

# %%
df1['Profit'] = df1.Rev - df1.Exp

# %%
df1
# Out:
#                        Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Kolkata_FMCG           NaN  874.40  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles          931.0  863.50  605    Pub    1935  NCR    0    NCRL
# Bangalore_Systems    900.0  881.60  650    Gov    1361  Blr    0    BSYS
# Chennai_Chemicals    966.0  863.20  608    Pub    1656  Che    1    CHEM
# Indi_Services        992.0  733.00  633    Gov   13023  NCR    0    INDI
# Chennai_Shipping     899.0  821.00  899    Pub     899  Che    1    SHIP
# Eastern_Estates      945.0  834.23  789   Prvt    1873  Kol    1    EEST
# Central_Services     934.0  824.00  689    Gov    1573  NCR    1    CSRV
# Deccan_Sporting      931.0  839.80  615   Prvt     154  Hyd    1    SPRT
# Bangalore_Breweries  966.0  875.00  674   Prvt     119  Blr    1    BREW
# Bombay_Finance       954.0  917.00  665    Pub    1443  Mum    0    BFIN
# NCR_Infra            921.0  843.50  615   Prvt    1635  NCR    0    NCIN
#
# ...

# %%
df1[df1.Profit < 0]
# Out:
#                     Vol    Rev  Exp Sector  EmpCnt   HQ  MNC StockID    GST  \
# Chennai_Shipping  899.0  821.0  899    Pub     899  Che    1    SHIP  Goods
#
#                  Start Date Taxpaid  Profit
# Chennai_Shipping   Nov 1930       0   -78.0

# %%
df1[(df1.Rev-df1.Exp) < 0]
# Out:
#                     Vol    Rev  Exp Sector  EmpCnt   HQ  MNC StockID    GST  \
# Chennai_Shipping  899.0  821.0  899    Pub     899  Che    1    SHIP  Goods
#
#                  Start Date Taxpaid  Profit
# Chennai_Shipping   Nov 1930       0   -78.0

# %%
df1.Rev.sum()
# Out:
# np.float64(10170.23)

# %%
df1.Rev.mean()
# Out:
# np.float64(847.5191666666666)

# %%
df1[df1.Rev > df1.Rev.mean()]
# Out:
#                        Vol    Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Kolkata_FMCG           NaN  874.4  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles          931.0  863.5  605    Pub    1935  NCR    0    NCRL
# Bangalore_Systems    900.0  881.6  650    Gov    1361  Blr    0    BSYS
# Chennai_Chemicals    966.0  863.2  608    Pub    1656  Che    1    CHEM
# Bangalore_Breweries  966.0  875.0  674   Prvt     119  Blr    1    BREW
# Bombay_Finance       954.0  917.0  665    Pub    1443  Mum    0    BFIN
#
#                           GST Start Date Taxpaid  Profit
# Kolkata_FMCG            Goods   Jan 1920  29.76$   198.4
# NCR_Leagles          Services   Feb 1960  38.78$   258.5
# Bangalore_Systems    Services   Apr 1950  34.74$   231.6
# Chennai_Chemicals       Goods   Aug 1928  38.28$   255.2
# Bangalore_Breweries     Goods   Oct 1971  19.65$   201.0
# Bombay_Finance       Services   Apr 1925   37.8$   252.0

# %%
df1[df1.Rev > df1.Rev.mean()]['EmpCnt']
# Out:
# Kolkata_FMCG           1379
# NCR_Leagles            1935
# Bangalore_Systems      1361
# Chennai_Chemicals      1656
# Bangalore_Breweries     119
# Bombay_Finance         1443
# Name: EmpCnt, dtype: int64

# %%
df1.loc[df1.Rev > df1.Rev.mean(),  'EmpCnt']
# Out:
# Kolkata_FMCG           1379
# NCR_Leagles            1935
# Bangalore_Systems      1361
# Chennai_Chemicals      1656
# Bangalore_Breweries     119
# Bombay_Finance         1443
# Name: EmpCnt, dtype: int64

# %%
df1.loc[df1.Rev > df1.Rev.mean(),  ['EmpCnt','Exp'] ]
# Out:
#                      EmpCnt  Exp
# Kolkata_FMCG           1379  676
# NCR_Leagles            1935  605
# Bangalore_Systems      1361  650
# Chennai_Chemicals      1656  608
# Bangalore_Breweries     119  674
# Bombay_Finance         1443  665

# %%
df1.columns != 'EmpCnt'
# Out:
# array([ True,  True,  True,  True, False,  True,  True,  True,  True,
#         True,  True,  True])

# %%
df1.loc[df1.Rev > df1.Rev.mean(),  df1.columns != 'EmpCnt' ]
# Out:
#                        Vol    Rev  Exp Sector   HQ  MNC StockID       GST  \
# Kolkata_FMCG           NaN  874.4  676    Pub  Kol    0    KFMC     Goods
# NCR_Leagles          931.0  863.5  605    Pub  NCR    0    NCRL  Services
# Bangalore_Systems    900.0  881.6  650    Gov  Blr    0    BSYS  Services
# Chennai_Chemicals    966.0  863.2  608    Pub  Che    1    CHEM     Goods
# Bangalore_Breweries  966.0  875.0  674   Prvt  Blr    1    BREW     Goods
# Bombay_Finance       954.0  917.0  665    Pub  Mum    0    BFIN  Services
#
#                     Start Date Taxpaid  Profit
# Kolkata_FMCG          Jan 1920  29.76$   198.4
# NCR_Leagles           Feb 1960  38.78$   258.5
# Bangalore_Systems     Apr 1950  34.74$   231.6
# Chennai_Chemicals     Aug 1928  38.28$   255.2
# Bangalore_Breweries   Oct 1971  19.65$   201.0
# Bombay_Finance        Apr 1925   37.8$   252.0

# %% [raw]
# Grammer
#
# Direct Access Mode
#
#     df1[col_label]  or df1.col_label
#     df1[ [list of col labels]  ]
#     df1[ row_label1 : row_label2 ]
#
# Integer Location Based Access
#     df1.iloc[row_n_index]
#     df1.iloc[row_n_index, col_n_index]
#
#     df1.iloc[row_n_slice]
#     df1.iloc[row_n_slice, col_n_slice]
#
#     df1.iloc[ [list of row n indices] ]
#     df1.iloc[ [list of row n indices], [list of col n indices] ]
#
#     combo of above
#
# Label Based Access
#     df1.loc[row_label]
#     df1.loc[row_label, col_label]
#
#     df1.loc[row_label_slice]
#     df1.loc[row_label_slice, col_label_slice]
#
#     df1.loc[ [list of row_labels] ]
#     df1.loc[ [list of row_labels], [list of col_labels] ]
#
#     df1.loc[ boolean series of len being number of observation, boolean series of len being number of features]
#
#      combo of above

# %%
df1
# Out:
#                        Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Kolkata_FMCG           NaN  874.40  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles          931.0  863.50  605    Pub    1935  NCR    0    NCRL
# Bangalore_Systems    900.0  881.60  650    Gov    1361  Blr    0    BSYS
# Chennai_Chemicals    966.0  863.20  608    Pub    1656  Che    1    CHEM
# Indi_Services        992.0  733.00  633    Gov   13023  NCR    0    INDI
# Chennai_Shipping     899.0  821.00  899    Pub     899  Che    1    SHIP
# Eastern_Estates      945.0  834.23  789   Prvt    1873  Kol    1    EEST
# Central_Services     934.0  824.00  689    Gov    1573  NCR    1    CSRV
# Deccan_Sporting      931.0  839.80  615   Prvt     154  Hyd    1    SPRT
# Bangalore_Breweries  966.0  875.00  674   Prvt     119  Blr    1    BREW
# Bombay_Finance       954.0  917.00  665    Pub    1443  Mum    0    BFIN
# NCR_Infra            921.0  843.50  615   Prvt    1635  NCR    0    NCIN
#
# ...

# %%
df1.head(3)
# Out:
#                      Vol    Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Kolkata_FMCG         NaN  874.4  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles        931.0  863.5  605    Pub    1935  NCR    0    NCRL
# Bangalore_Systems  900.0  881.6  650    Gov    1361  Blr    0    BSYS
#
#                         GST Start Date Taxpaid  Profit
# Kolkata_FMCG          Goods   Jan 1920  29.76$   198.4
# NCR_Leagles        Services   Feb 1960  38.78$   258.5
# Bangalore_Systems  Services   Apr 1950  34.74$   231.6

# %%
df1.tail(3)
# Out:
#                        Vol    Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Bangalore_Breweries  966.0  875.0  674   Prvt     119  Blr    1    BREW
# Bombay_Finance       954.0  917.0  665    Pub    1443  Mum    0    BFIN
# NCR_Infra            921.0  843.5  615   Prvt    1635  NCR    0    NCIN
#
#                           GST Start Date Taxpaid  Profit
# Bangalore_Breweries     Goods   Oct 1971  19.65$   201.0
# Bombay_Finance       Services   Apr 1925   37.8$   252.0
# NCR_Infra            Services   Feb 1920  34.27$   228.5

# %%
df1.shape
# Out:
# (12, 12)

# %%
df1.ndim
# Out:
# 2

# %%
df1.index
# Out:
# Index(['Kolkata_FMCG', 'NCR_Leagles', 'Bangalore_Systems', 'Chennai_Chemicals',
#        'Indi_Services', 'Chennai_Shipping', 'Eastern_Estates',
#        'Central_Services', 'Deccan_Sporting', 'Bangalore_Breweries',
#        'Bombay_Finance', 'NCR_Infra'],
#       dtype='str')

# %%
df1.columns
# Out:
# Index(['Vol', 'Rev', 'Exp', 'Sector', 'EmpCnt', 'HQ', 'MNC', 'StockID', 'GST',
#        'Start Date', 'Taxpaid', 'Profit'],
#       dtype='str')

# %%
df1.values
# Out:
# array([[nan, 874.4, 676, 'Pub', 1379, 'Kol', 0, 'KFMC', 'Goods',
#         'Jan 1920', '29.76$', 198.39999999999998],
#        [931.0, 863.5, 605, 'Pub', 1935, 'NCR', 0, 'NCRL', 'Services',
#         'Feb 1960', '38.78$', 258.5],
#        [900.0, 881.6, 650, 'Gov', 1361, 'Blr', 0, 'BSYS', 'Services',
#         'Apr 1950', '34.74$', 231.60000000000002],
#        [966.0, 863.2, 608, 'Pub', 1656, 'Che', 1, 'CHEM', 'Goods',
#         'Aug 1928', '38.28$', 255.20000000000005],
#        [992.0, 733.0, 633, 'Gov', 13023, 'NCR', 0, 'INDI', 'Services',
#         'Mar 1920', '15$', 100.0],
#        [899.0, 821.0, 899, 'Pub', 899, 'Che', 1, 'SHIP', 'Goods',
#         'Nov 1930', '0', -78.0],
#        [945.0, 834.23, 789, 'Prvt', 1873, 'Kol', 1, 'EEST', 'Goods',
#         'Jan 1994', '6.78$', 45.23000000000002],
#        [934.0, 824.0, 689, 'Gov', 1573, 'NCR', 1, 'CSRV', 'Services',
#         'Jun 1974', '20.25$', 135.0],
#        [931.0, 839.8, 615, 'Prvt', 154, 'Hyd', 1, 'SPRT', 'Services',
# ...

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 12 entries, Kolkata_FMCG to NCR_Infra
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Vol         11 non-null     float64
#  1   Rev         12 non-null     float64
#  2   Exp         12 non-null     int64
#  3   Sector      12 non-null     str
#  4   EmpCnt      12 non-null     int64
#  5   HQ          12 non-null     str
#  6   MNC         12 non-null     int64
#  7   StockID     12 non-null     str
#  8   GST         12 non-null     str
#  9   Start Date  12 non-null     str
#  10  Taxpaid     12 non-null     str
#  11  Profit      12 non-null     float64
# dtypes: float64(3), int64(3), str(6)
# memory usage: 1.5+ KB

# %%
df1.describe()
# Out:
#               Vol         Rev         Exp        EmpCnt        MNC      Profit
# count   11.000000   12.000000   12.000000     12.000000  12.000000   12.000000
# mean   939.909091  847.519167  676.500000   2254.166667   0.500000  171.019167
# std     28.490190   45.318608   86.561066   3443.674751   0.522233  103.126925
# min    899.000000  733.000000  605.000000    119.000000   0.000000  -78.000000
# 25%    926.000000  831.672500  615.000000   1245.500000   0.000000  126.250000
# 50%    934.000000  853.350000  657.500000   1508.000000   0.500000  212.900000
# 75%    960.000000  874.550000  679.250000   1710.250000   1.000000  236.700000
# max    992.000000  917.000000  899.000000  13023.000000   1.000000  258.500000

# %%
df1.describe(include='all')
# Out:
#                Vol         Rev         Exp Sector        EmpCnt   HQ  \
# count    11.000000   12.000000   12.000000     12     12.000000   12
# unique         NaN         NaN         NaN      3           NaN    6
# top            NaN         NaN         NaN    Pub           NaN  NCR
# freq           NaN         NaN         NaN      5           NaN    4
# mean    939.909091  847.519167  676.500000    NaN   2254.166667  NaN
# std      28.490190   45.318608   86.561066    NaN   3443.674751  NaN
# min     899.000000  733.000000  605.000000    NaN    119.000000  NaN
# 25%     926.000000  831.672500  615.000000    NaN   1245.500000  NaN
# 50%     934.000000  853.350000  657.500000    NaN   1508.000000  NaN
# 75%     960.000000  874.550000  679.250000    NaN   1710.250000  NaN
# max     992.000000  917.000000  899.000000    NaN  13023.000000  NaN
#
#               MNC StockID       GST Start Date Taxpaid      Profit
# count   12.000000      12        12         12      12   12.000000
# ...

# %%
df1.describe(include=np.int64)
# Out:
#               Exp        EmpCnt        MNC
# count   12.000000     12.000000  12.000000
# mean   676.500000   2254.166667   0.500000
# std     86.561066   3443.674751   0.522233
# min    605.000000    119.000000   0.000000
# 25%    615.000000   1245.500000   0.000000
# 50%    657.500000   1508.000000   0.500000
# 75%    679.250000   1710.250000   1.000000
# max    899.000000  13023.000000   1.000000

# %%
df1
# Out:
#                        Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Kolkata_FMCG           NaN  874.40  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles          931.0  863.50  605    Pub    1935  NCR    0    NCRL
# Bangalore_Systems    900.0  881.60  650    Gov    1361  Blr    0    BSYS
# Chennai_Chemicals    966.0  863.20  608    Pub    1656  Che    1    CHEM
# Indi_Services        992.0  733.00  633    Gov   13023  NCR    0    INDI
# Chennai_Shipping     899.0  821.00  899    Pub     899  Che    1    SHIP
# Eastern_Estates      945.0  834.23  789   Prvt    1873  Kol    1    EEST
# Central_Services     934.0  824.00  689    Gov    1573  NCR    1    CSRV
# Deccan_Sporting      931.0  839.80  615   Prvt     154  Hyd    1    SPRT
# Bangalore_Breweries  966.0  875.00  674   Prvt     119  Blr    1    BREW
# Bombay_Finance       954.0  917.00  665    Pub    1443  Mum    0    BFIN
# NCR_Infra            921.0  843.50  615   Prvt    1635  NCR    0    NCIN
#
# ...

# %%
df1.Sector.count()
# Out:
# np.int64(12)

# %%
df1.Sector.value_counts()
# Out:
# Sector
# Pub     5
# Prvt    4
# Gov     3
# Name: count, dtype: int64

# %%
df1.Rev.max()
# Out:
# np.float64(917.0)

# %%
df1.Rev.min()
# Out:
# np.float64(733.0)

# %%
df1.Rev.mean()
# Out:
# np.float64(847.5191666666666)

# %%
df1.Rev.std()
# Out:
# np.float64(45.31860794988249)

# %%
df1.Rev.var()
# Out:
# np.float64(2053.7762265151523)

# %%
df1['Rev'].var()
# Out:
# np.float64(2053.7762265151523)

# %% [markdown]
# # Saving  the DF

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds1.csv')
df1
# Out:
#                      Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Kolkata_FMCG         925  874.40  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles          931  863.50  605    Pub    1935  NCR    0    NCRL
# Bangalore_Systems    900  881.60  650    Gov    1361  Blr    0    BSYS
# Chennai_Chemicals    966  863.20  608    Pub    1656  Che    1    CHEM
# Indi_Services        992  733.00  633    Gov   13023  NCR    0    INDI
# Chennai_Shipping     899  821.00  899    Pub     899  Che    1    SHIP
# Eastern_Estates      945  834.23  789   Prvt    1873  Kol    1    EEST
# Central_Services     934  824.00  689    Gov    1573  NCR    1    CSRV
# Deccan_Sporting      931  839.80  615   Prvt     154  Hyd    1    SPRT
# Bangalore_Breweries  966  875.00  674   Prvt     119  Blr    1    BREW
# Bombay_Finance       954  917.00  665    Pub    1443  Mum    0    BFIN
# NCR_Infra            921  843.50  615   Prvt    1635  NCR    0    NCIN
#
# ...

# %%
df1.to_csv('file1.csv')

# %%
df1.to_html('file1.html')

# %%
df1.to_json('file1.json')

# %%
df10 = pd.read_csv('file1.csv', index_col=0)
df10
# Out:
#                      Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Kolkata_FMCG         925  874.40  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles          931  863.50  605    Pub    1935  NCR    0    NCRL
# Bangalore_Systems    900  881.60  650    Gov    1361  Blr    0    BSYS
# Chennai_Chemicals    966  863.20  608    Pub    1656  Che    1    CHEM
# Indi_Services        992  733.00  633    Gov   13023  NCR    0    INDI
# Chennai_Shipping     899  821.00  899    Pub     899  Che    1    SHIP
# Eastern_Estates      945  834.23  789   Prvt    1873  Kol    1    EEST
# Central_Services     934  824.00  689    Gov    1573  NCR    1    CSRV
# Deccan_Sporting      931  839.80  615   Prvt     154  Hyd    1    SPRT
# Bangalore_Breweries  966  875.00  674   Prvt     119  Blr    1    BREW
# Bombay_Finance       954  917.00  665    Pub    1443  Mum    0    BFIN
# NCR_Infra            921  843.50  615   Prvt    1635  NCR    0    NCIN
#
# ...

# %%
df12 = pd.read_json('file1.json')
df12

# %% [markdown]
# # Sorting

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds1.csv')
df1
# Out:
#                      Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Kolkata_FMCG         925  874.40  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles          931  863.50  605    Pub    1935  NCR    0    NCRL
# Bangalore_Systems    900  881.60  650    Gov    1361  Blr    0    BSYS
# Chennai_Chemicals    966  863.20  608    Pub    1656  Che    1    CHEM
# Indi_Services        992  733.00  633    Gov   13023  NCR    0    INDI
# Chennai_Shipping     899  821.00  899    Pub     899  Che    1    SHIP
# Eastern_Estates      945  834.23  789   Prvt    1873  Kol    1    EEST
# Central_Services     934  824.00  689    Gov    1573  NCR    1    CSRV
# Deccan_Sporting      931  839.80  615   Prvt     154  Hyd    1    SPRT
# Bangalore_Breweries  966  875.00  674   Prvt     119  Blr    1    BREW
# Bombay_Finance       954  917.00  665    Pub    1443  Mum    0    BFIN
# NCR_Infra            921  843.50  615   Prvt    1635  NCR    0    NCIN
#
# ...

# %%
df2 = df1.sort_index(axis=0, inplace=False)
print(df2)
# Out:
#                      Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Bangalore_Breweries  966  875.00  674   Prvt     119  Blr    1    BREW
# Bangalore_Systems    900  881.60  650    Gov    1361  Blr    0    BSYS
# Bombay_Finance       954  917.00  665    Pub    1443  Mum    0    BFIN
# Central_Services     934  824.00  689    Gov    1573  NCR    1    CSRV
# Chennai_Chemicals    966  863.20  608    Pub    1656  Che    1    CHEM
# Chennai_Shipping     899  821.00  899    Pub     899  Che    1    SHIP
# Deccan_Sporting      931  839.80  615   Prvt     154  Hyd    1    SPRT
# Eastern_Estates      945  834.23  789   Prvt    1873  Kol    1    EEST
# Indi_Services        992  733.00  633    Gov   13023  NCR    0    INDI
# Kolkata_FMCG         925  874.40  676    Pub    1379  Kol    0    KFMC
# NCR_Infra            921  843.50  615   Prvt    1635  NCR    0    NCIN
# NCR_Leagles          931  863.50  605    Pub    1935  NCR    0    NCRL
#
# ...

# %%
df1

# %%
df3 = df1.sort_index(axis=1, inplace=False)
df3
# Out:
#                      EmpCnt  Exp       GST   HQ  MNC     Rev Sector  \
# Kolkata_FMCG           1379  676     Goods  Kol    0  874.40    Pub
# NCR_Leagles            1935  605  Services  NCR    0  863.50    Pub
# Bangalore_Systems      1361  650  Services  Blr    0  881.60    Gov
# Chennai_Chemicals      1656  608     Goods  Che    1  863.20    Pub
# Indi_Services         13023  633  Services  NCR    0  733.00    Gov
# Chennai_Shipping        899  899     Goods  Che    1  821.00    Pub
# Eastern_Estates        1873  789     Goods  Kol    1  834.23   Prvt
# Central_Services       1573  689  Services  NCR    1  824.00    Gov
# Deccan_Sporting         154  615  Services  Hyd    1  839.80   Prvt
# Bangalore_Breweries     119  674     Goods  Blr    1  875.00   Prvt
# Bombay_Finance         1443  665  Services  Mum    0  917.00    Pub
# NCR_Infra              1635  615  Services  NCR    0  843.50   Prvt
#
#                     Start Date StockID Taxpaid  Vol
# ...

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds1.csv')
df1 = df1.sort_index(axis=0, inplace=False).sort_index(axis=1, inplace=False)
df1

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds1.csv')
df1

# %%
df1.sort_values(by='Vol',ascending=True)
# Out:
#                      Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Chennai_Shipping     899  821.00  899    Pub     899  Che    1    SHIP
# Bangalore_Systems    900  881.60  650    Gov    1361  Blr    0    BSYS
# NCR_Infra            921  843.50  615   Prvt    1635  NCR    0    NCIN
# Kolkata_FMCG         925  874.40  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles          931  863.50  605    Pub    1935  NCR    0    NCRL
# Deccan_Sporting      931  839.80  615   Prvt     154  Hyd    1    SPRT
# Central_Services     934  824.00  689    Gov    1573  NCR    1    CSRV
# Eastern_Estates      945  834.23  789   Prvt    1873  Kol    1    EEST
# Bombay_Finance       954  917.00  665    Pub    1443  Mum    0    BFIN
# Chennai_Chemicals    966  863.20  608    Pub    1656  Che    1    CHEM
# Bangalore_Breweries  966  875.00  674   Prvt     119  Blr    1    BREW
# Indi_Services        992  733.00  633    Gov   13023  NCR    0    INDI
#
# ...

# %%
df1.sort_values(by=['Vol','Rev'],ascending=True)
# Out:
#                      Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Chennai_Shipping     899  821.00  899    Pub     899  Che    1    SHIP
# Bangalore_Systems    900  881.60  650    Gov    1361  Blr    0    BSYS
# NCR_Infra            921  843.50  615   Prvt    1635  NCR    0    NCIN
# Kolkata_FMCG         925  874.40  676    Pub    1379  Kol    0    KFMC
# Deccan_Sporting      931  839.80  615   Prvt     154  Hyd    1    SPRT
# NCR_Leagles          931  863.50  605    Pub    1935  NCR    0    NCRL
# Central_Services     934  824.00  689    Gov    1573  NCR    1    CSRV
# Eastern_Estates      945  834.23  789   Prvt    1873  Kol    1    EEST
# Bombay_Finance       954  917.00  665    Pub    1443  Mum    0    BFIN
# Chennai_Chemicals    966  863.20  608    Pub    1656  Che    1    CHEM
# Bangalore_Breweries  966  875.00  674   Prvt     119  Blr    1    BREW
# Indi_Services        992  733.00  633    Gov   13023  NCR    0    INDI
#
# ...

# %%
df1.sort_values(by=['Vol','Rev'],ascending=[True,False])

# %%
df1.sort_values(by='NCR_Leagles',ascending=True, axis=1) # will not work. heterogenous values

# %% [markdown]
# # Ranking

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds1.csv')
df1
# Out:
#                      Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Kolkata_FMCG         925  874.40  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles          931  863.50  605    Pub    1935  NCR    0    NCRL
# Bangalore_Systems    900  881.60  650    Gov    1361  Blr    0    BSYS
# Chennai_Chemicals    966  863.20  608    Pub    1656  Che    1    CHEM
# Indi_Services        992  733.00  633    Gov   13023  NCR    0    INDI
# Chennai_Shipping     899  821.00  899    Pub     899  Che    1    SHIP
# Eastern_Estates      945  834.23  789   Prvt    1873  Kol    1    EEST
# Central_Services     934  824.00  689    Gov    1573  NCR    1    CSRV
# Deccan_Sporting      931  839.80  615   Prvt     154  Hyd    1    SPRT
# Bangalore_Breweries  966  875.00  674   Prvt     119  Blr    1    BREW
# Bombay_Finance       954  917.00  665    Pub    1443  Mum    0    BFIN
# NCR_Infra            921  843.50  615   Prvt    1635  NCR    0    NCIN
#
# ...

# %%
df1['rank'] = df1.Vol.rank(ascending=False, method='average')
df1
# Out:
#                      Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Kolkata_FMCG         925  874.40  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles          931  863.50  605    Pub    1935  NCR    0    NCRL
# Bangalore_Systems    900  881.60  650    Gov    1361  Blr    0    BSYS
# Chennai_Chemicals    966  863.20  608    Pub    1656  Che    1    CHEM
# Indi_Services        992  733.00  633    Gov   13023  NCR    0    INDI
# Chennai_Shipping     899  821.00  899    Pub     899  Che    1    SHIP
# Eastern_Estates      945  834.23  789   Prvt    1873  Kol    1    EEST
# Central_Services     934  824.00  689    Gov    1573  NCR    1    CSRV
# Deccan_Sporting      931  839.80  615   Prvt     154  Hyd    1    SPRT
# Bangalore_Breweries  966  875.00  674   Prvt     119  Blr    1    BREW
# Bombay_Finance       954  917.00  665    Pub    1443  Mum    0    BFIN
# NCR_Infra            921  843.50  615   Prvt    1635  NCR    0    NCIN
#
# ...

# %%
df1['rank'] = df1.Vol.rank(ascending=False, method='first')
df1
# Out:
#                      Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Kolkata_FMCG         925  874.40  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles          931  863.50  605    Pub    1935  NCR    0    NCRL
# Bangalore_Systems    900  881.60  650    Gov    1361  Blr    0    BSYS
# Chennai_Chemicals    966  863.20  608    Pub    1656  Che    1    CHEM
# Indi_Services        992  733.00  633    Gov   13023  NCR    0    INDI
# Chennai_Shipping     899  821.00  899    Pub     899  Che    1    SHIP
# Eastern_Estates      945  834.23  789   Prvt    1873  Kol    1    EEST
# Central_Services     934  824.00  689    Gov    1573  NCR    1    CSRV
# Deccan_Sporting      931  839.80  615   Prvt     154  Hyd    1    SPRT
# Bangalore_Breweries  966  875.00  674   Prvt     119  Blr    1    BREW
# Bombay_Finance       954  917.00  665    Pub    1443  Mum    0    BFIN
# NCR_Infra            921  843.50  615   Prvt    1635  NCR    0    NCIN
#
# ...

# %%
df1['rank'] = df1.Vol.rank(ascending=False, method='min')
df1
# Out:
#                      Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Kolkata_FMCG         925  874.40  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles          931  863.50  605    Pub    1935  NCR    0    NCRL
# Bangalore_Systems    900  881.60  650    Gov    1361  Blr    0    BSYS
# Chennai_Chemicals    966  863.20  608    Pub    1656  Che    1    CHEM
# Indi_Services        992  733.00  633    Gov   13023  NCR    0    INDI
# Chennai_Shipping     899  821.00  899    Pub     899  Che    1    SHIP
# Eastern_Estates      945  834.23  789   Prvt    1873  Kol    1    EEST
# Central_Services     934  824.00  689    Gov    1573  NCR    1    CSRV
# Deccan_Sporting      931  839.80  615   Prvt     154  Hyd    1    SPRT
# Bangalore_Breweries  966  875.00  674   Prvt     119  Blr    1    BREW
# Bombay_Finance       954  917.00  665    Pub    1443  Mum    0    BFIN
# NCR_Infra            921  843.50  615   Prvt    1635  NCR    0    NCIN
#
# ...

# %%
df1['rank'] = df1.Vol.rank(ascending=False, method='max')
df1
# Out:
#                      Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Kolkata_FMCG         925  874.40  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles          931  863.50  605    Pub    1935  NCR    0    NCRL
# Bangalore_Systems    900  881.60  650    Gov    1361  Blr    0    BSYS
# Chennai_Chemicals    966  863.20  608    Pub    1656  Che    1    CHEM
# Indi_Services        992  733.00  633    Gov   13023  NCR    0    INDI
# Chennai_Shipping     899  821.00  899    Pub     899  Che    1    SHIP
# Eastern_Estates      945  834.23  789   Prvt    1873  Kol    1    EEST
# Central_Services     934  824.00  689    Gov    1573  NCR    1    CSRV
# Deccan_Sporting      931  839.80  615   Prvt     154  Hyd    1    SPRT
# Bangalore_Breweries  966  875.00  674   Prvt     119  Blr    1    BREW
# Bombay_Finance       954  917.00  665    Pub    1443  Mum    0    BFIN
# NCR_Infra            921  843.50  615   Prvt    1635  NCR    0    NCIN
#
# ...

# %%
df1['rank'] = df1.Vol.rank(ascending=False, method='dense')
df1
# Out:
#                      Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Kolkata_FMCG         925  874.40  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles          931  863.50  605    Pub    1935  NCR    0    NCRL
# Bangalore_Systems    900  881.60  650    Gov    1361  Blr    0    BSYS
# Chennai_Chemicals    966  863.20  608    Pub    1656  Che    1    CHEM
# Indi_Services        992  733.00  633    Gov   13023  NCR    0    INDI
# Chennai_Shipping     899  821.00  899    Pub     899  Che    1    SHIP
# Eastern_Estates      945  834.23  789   Prvt    1873  Kol    1    EEST
# Central_Services     934  824.00  689    Gov    1573  NCR    1    CSRV
# Deccan_Sporting      931  839.80  615   Prvt     154  Hyd    1    SPRT
# Bangalore_Breweries  966  875.00  674   Prvt     119  Blr    1    BREW
# Bombay_Finance       954  917.00  665    Pub    1443  Mum    0    BFIN
# NCR_Infra            921  843.50  615   Prvt    1635  NCR    0    NCIN
#
# ...

# %% [markdown]
# # Concatenation

# %%
df11 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds11.csv')
df11
# Out:
#                  Vol    Rev  Exp Sector  EmpCnt
# Kolkata_FMCG     900  874.4  676    Pub    1379
# NCR_Leagles      931  863.5  605    Pub    1935
# Bombay_Sporting  975  839.8  615    Pvt     154

# %%
df12 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds12.csv')
df12
# Out:
#                    Vol    Rev  Exp Sector   HQ
# Bombay_Sporting    925  839.8  715    Pvt  Mum
# Bombay_Finance     899  917.0  674    Pub  Mum
# Bangalore_Systems  931  881.6  650    Gov  Blr
# Chennai_Shipping   992  821.0  665    Pub  Che

# %%
df13 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds13.csv')
df13
# Out:
#                      Vol    Rev  Exp Sector  EmpCnt   HQ
# Bangalore_Breweries  966  805.0  895    Pvt     119  Blr
# Chennai_Chemicals    966  863.2  608    Pub    1656  Che
# Indi_Services        954  733.0  609    Gov   13023  NCR

# %%
dfc = pd.concat(objs=(df11,df12),join='outer',axis=0)
dfc
# Out:
#                    Vol    Rev  Exp Sector  EmpCnt   HQ
# Kolkata_FMCG       900  874.4  676    Pub  1379.0  NaN
# NCR_Leagles        931  863.5  605    Pub  1935.0  NaN
# Bombay_Sporting    975  839.8  615    Pvt   154.0  NaN
# Bombay_Sporting    925  839.8  715    Pvt     NaN  Mum
# Bombay_Finance     899  917.0  674    Pub     NaN  Mum
# Bangalore_Systems  931  881.6  650    Gov     NaN  Blr
# Chennai_Shipping   992  821.0  665    Pub     NaN  Che

# %%
dfc = pd.concat(objs=(df11,df12),join='inner',axis=0)
dfc
# Out:
#                    Vol    Rev  Exp Sector
# Kolkata_FMCG       900  874.4  676    Pub
# NCR_Leagles        931  863.5  605    Pub
# Bombay_Sporting    975  839.8  615    Pvt
# Bombay_Sporting    925  839.8  715    Pvt
# Bombay_Finance     899  917.0  674    Pub
# Bangalore_Systems  931  881.6  650    Gov
# Chennai_Shipping   992  821.0  665    Pub

# %%
dfc = pd.concat(objs=(df11,df12),join='inner',axis=0,  keys=['frame11', 'frame12'])
dfc
# Out:
#                            Vol    Rev  Exp Sector
# frame11 Kolkata_FMCG       900  874.4  676    Pub
#         NCR_Leagles        931  863.5  605    Pub
#         Bombay_Sporting    975  839.8  615    Pvt
# frame12 Bombay_Sporting    925  839.8  715    Pvt
#         Bombay_Finance     899  917.0  674    Pub
#         Bangalore_Systems  931  881.6  650    Gov
#         Chennai_Shipping   992  821.0  665    Pub

# %%
dfc.index
# Out:
# MultiIndex([('frame11',      'Kolkata_FMCG'),
#             ('frame11',       'NCR_Leagles'),
#             ('frame11',   'Bombay_Sporting'),
#             ('frame12',   'Bombay_Sporting'),
#             ('frame12',    'Bombay_Finance'),
#             ('frame12', 'Bangalore_Systems'),
#             ('frame12',  'Chennai_Shipping')],
#            )

# %%
dfc.loc[('frame12',    'Bombay_Finance'),'Rev']

# %%
dfc = pd.concat(objs=(df11,df12),join='outer',axis=1)
dfc
# Out:
#                      Vol    Rev    Exp Sector  EmpCnt    Vol    Rev    Exp  \
# Kolkata_FMCG       900.0  874.4  676.0    Pub  1379.0    NaN    NaN    NaN
# NCR_Leagles        931.0  863.5  605.0    Pub  1935.0    NaN    NaN    NaN
# Bombay_Sporting    975.0  839.8  615.0    Pvt   154.0  925.0  839.8  715.0
# Bombay_Finance       NaN    NaN    NaN    NaN     NaN  899.0  917.0  674.0
# Bangalore_Systems    NaN    NaN    NaN    NaN     NaN  931.0  881.6  650.0
# Chennai_Shipping     NaN    NaN    NaN    NaN     NaN  992.0  821.0  665.0
#
#                   Sector   HQ
# Kolkata_FMCG         NaN  NaN
# NCR_Leagles          NaN  NaN
# Bombay_Sporting      Pvt  Mum
# Bombay_Finance       Pub  Mum
# Bangalore_Systems    Gov  Blr
# Chennai_Shipping     Pub  Che

# %%
dfc = pd.concat(objs=(df11,df12),join='inner',axis=1,  keys=['frame11', 'frame12'])
dfc
# Out:
#                 frame11                           frame12                     \
#                     Vol    Rev  Exp Sector EmpCnt     Vol    Rev  Exp Sector
# Bombay_Sporting     975  839.8  615    Pvt    154     925  839.8  715    Pvt
#
#
#                   HQ
# Bombay_Sporting  Mum

# %%
dfc.index

# %%
dfc.columns

# %%
dfc.loc['Bombay_Sporting',('frame12',    'Vol') ]

# %% [markdown]
# # Merge

# %% [markdown]
# ## Merge Datasets

# %%
df21 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds21.csv')
df21
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df21 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds21.csv')
#       2 df21
#
# NameError: name 'pd' is not defined

# %%
df22 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds22.csv')
df22
# Out:
#                     stock_name   HQ  vol
# Bangalore_Breweries       BREW  Blr  350
# Bombay_Finance            BFIN  Mum  450
# Chennai_Chemicals         CHEM  Che  550
# Kolkata_FMCG              KFMC  Kol  500

# %%
df23 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds23.csv')
df23
# Out:
#                     stock_name   HQ  empcnt
# Chennai_Shipping          SHIP  Che   10000
# Bangalore_Breweries       BREW  Blr    5000
# Bombay_Finance            BFIN  Mum   30000
# Bangalore_Systems         BSYS  Blr   20000

# %%
print(df21)
print(df22)
print()
dfm = pd.merge(df21,df22, how='inner', on='HQ', indicator=True)
print(dfm)
# Out:
#                     stock_id   HQ  high
# Bangalore_Breweries     BREW  Blr  1100
# Chennai_Shipping        SHIP  Che  1200
# Kolkata_FMCG            KFMC  Kol  2000
# NCR_Leagles             NCRL  NCR  1200
#                     stock_name   HQ  vol
# Bangalore_Breweries       BREW  Blr  350
# Bombay_Finance            BFIN  Mum  450
# Chennai_Chemicals         CHEM  Che  550
# Kolkata_FMCG              KFMC  Kol  500
#
#   stock_id   HQ  high stock_name  vol _merge
# 0     BREW  Blr  1100       BREW  350   both
# 1     SHIP  Che  1200       CHEM  550   both
# 2     KFMC  Kol  2000       KFMC  500   both

# %%
print(df21)
print(df22)
print()
dfm = pd.merge(df21,df22, how='outer', on='HQ', indicator=True)
print(dfm)
# Out:
#                     stock_id   HQ  high
# Bangalore_Breweries     BREW  Blr  1100
# Chennai_Shipping        SHIP  Che  1200
# Kolkata_FMCG            KFMC  Kol  2000
# NCR_Leagles             NCRL  NCR  1200
#                     stock_name   HQ  vol
# Bangalore_Breweries       BREW  Blr  350
# Bombay_Finance            BFIN  Mum  450
# Chennai_Chemicals         CHEM  Che  550
# Kolkata_FMCG              KFMC  Kol  500
#
#   stock_id   HQ    high stock_name    vol      _merge
# 0     BREW  Blr  1100.0       BREW  350.0        both
# 1     SHIP  Che  1200.0       CHEM  550.0        both
# 2     KFMC  Kol  2000.0       KFMC  500.0        both
# 3      NaN  Mum     NaN       BFIN  450.0  right_only
# 4     NCRL  NCR  1200.0        NaN    NaN   left_only

# %%
print(df21)
print(df22)
print()
dfm = pd.merge(df21,df22, how='left', on='HQ', indicator=True)
print(dfm)
# Out:
#                     stock_id   HQ  high
# Bangalore_Breweries     BREW  Blr  1100
# Chennai_Shipping        SHIP  Che  1200
# Kolkata_FMCG            KFMC  Kol  2000
# NCR_Leagles             NCRL  NCR  1200
#                     stock_name   HQ  vol
# Bangalore_Breweries       BREW  Blr  350
# Bombay_Finance            BFIN  Mum  450
# Chennai_Chemicals         CHEM  Che  550
# Kolkata_FMCG              KFMC  Kol  500
#
#   stock_id   HQ  high stock_name    vol     _merge
# 0     BREW  Blr  1100       BREW  350.0       both
# 1     SHIP  Che  1200       CHEM  550.0       both
# 2     KFMC  Kol  2000       KFMC  500.0       both
# 3     NCRL  NCR  1200        NaN    NaN  left_only

# %%
print(df21)
print(df22)
print()
dfm = pd.merge(df21,df22, how='right', on='HQ', indicator=True)
print(dfm)
# Out:
#                     stock_id   HQ  high
# Bangalore_Breweries     BREW  Blr  1100
# Chennai_Shipping        SHIP  Che  1200
# Kolkata_FMCG            KFMC  Kol  2000
# NCR_Leagles             NCRL  NCR  1200
#                     stock_name   HQ  vol
# Bangalore_Breweries       BREW  Blr  350
# Bombay_Finance            BFIN  Mum  450
# Chennai_Chemicals         CHEM  Che  550
# Kolkata_FMCG              KFMC  Kol  500
#
#   stock_id   HQ    high stock_name  vol      _merge
# 0     BREW  Blr  1100.0       BREW  350        both
# 1      NaN  Mum     NaN       BFIN  450  right_only
# 2     SHIP  Che  1200.0       CHEM  550        both
# 3     KFMC  Kol  2000.0       KFMC  500        both

# %%
print(df21)
print(df22)
print()
dfm = pd.merge(df21,df22, how='cross',indicator=True)
print(dfm)
# Out:
#                     stock_id   HQ  high
# Bangalore_Breweries     BREW  Blr  1100
# Chennai_Shipping        SHIP  Che  1200
# Kolkata_FMCG            KFMC  Kol  2000
# NCR_Leagles             NCRL  NCR  1200
#                     stock_name   HQ  vol
# Bangalore_Breweries       BREW  Blr  350
# Bombay_Finance            BFIN  Mum  450
# Chennai_Chemicals         CHEM  Che  550
# Kolkata_FMCG              KFMC  Kol  500
#
#    stock_id HQ_x  high stock_name HQ_y  vol _merge
# 0      BREW  Blr  1100       BREW  Blr  350   both
# 1      BREW  Blr  1100       BFIN  Mum  450   both
# 2      BREW  Blr  1100       CHEM  Che  550   both
# 3      BREW  Blr  1100       KFMC  Kol  500   both
# 4      SHIP  Che  1200       BREW  Blr  350   both
# 5      SHIP  Che  1200       BFIN  Mum  450   both
# 6      SHIP  Che  1200       CHEM  Che  550   both
# 7      SHIP  Che  1200       KFMC  Kol  500   both
# 8      KFMC  Kol  2000       BREW  Blr  350   both
# ...

# %%
print(df22)
print(df23)
print()
dfm = pd.merge(df22,df23, how='inner',on='HQ', indicator=True)
print(dfm)
# Out:
#                     stock_name   HQ  vol
# Bangalore_Breweries       BREW  Blr  350
# Bombay_Finance            BFIN  Mum  450
# Chennai_Chemicals         CHEM  Che  550
# Kolkata_FMCG              KFMC  Kol  500
#                     stock_name   HQ  empcnt
# Chennai_Shipping          SHIP  Che   10000
# Bangalore_Breweries       BREW  Blr    5000
# Bombay_Finance            BFIN  Mum   30000
# Bangalore_Systems         BSYS  Blr   20000
#
#   stock_name_x   HQ  vol stock_name_y  empcnt _merge
# 0         BREW  Blr  350         BREW    5000   both
# 1         BREW  Blr  350         BSYS   20000   both
# 2         BFIN  Mum  450         BFIN   30000   both
# 3         CHEM  Che  550         SHIP   10000   both

# %%
print(df21)
print(df22)
print()
dfm = pd.merge(df21,df22, how='inner',left_on='stock_id', 
               right_on='stock_name',indicator=True)
print(dfm)
# Out:
#                     stock_id   HQ  high
# Bangalore_Breweries     BREW  Blr  1100
# Chennai_Shipping        SHIP  Che  1200
# Kolkata_FMCG            KFMC  Kol  2000
# NCR_Leagles             NCRL  NCR  1200
#                     stock_name   HQ  vol
# Bangalore_Breweries       BREW  Blr  350
# Bombay_Finance            BFIN  Mum  450
# Chennai_Chemicals         CHEM  Che  550
# Kolkata_FMCG              KFMC  Kol  500
#
#   stock_id HQ_x  high stock_name HQ_y  vol _merge
# 0     BREW  Blr  1100       BREW  Blr  350   both
# 1     KFMC  Kol  2000       KFMC  Kol  500   both

# %% [markdown]
# # Rename of Indices

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds1.csv')
df1

# %%
df1.rename(index={'Indi_Services':'IR','Bangalore_Breweries':'UB' }, 
           columns={'Vol':'Volume','abc':'xyz'})

# %% [markdown]
# # Pivot Table

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds1.csv')
df1
# Out:
#                      Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Kolkata_FMCG         925  874.40  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles          931  863.50  605    Pub    1935  NCR    0    NCRL
# Bangalore_Systems    900  881.60  650    Gov    1361  Blr    0    BSYS
# Chennai_Chemicals    966  863.20  608    Pub    1656  Che    1    CHEM
# Indi_Services        992  733.00  633    Gov   13023  NCR    0    INDI
# Chennai_Shipping     899  821.00  899    Pub     899  Che    1    SHIP
# Eastern_Estates      945  834.23  789   Prvt    1873  Kol    1    EEST
# Central_Services     934  824.00  689    Gov    1573  NCR    1    CSRV
# Deccan_Sporting      931  839.80  615   Prvt     154  Hyd    1    SPRT
# Bangalore_Breweries  966  875.00  674   Prvt     119  Blr    1    BREW
# Bombay_Finance       954  917.00  665    Pub    1443  Mum    0    BFIN
# NCR_Infra            921  843.50  615   Prvt    1635  NCR    0    NCIN
#
# ...

# %%
pd.pivot_table(df1, index='Sector')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# ...

# %%
dfp = pd.pivot_table(df1, index='Sector', values=['Vol','Exp','Rev'])
dfp
# Out:
#                Exp         Rev     Vol
# Sector
# Gov     657.333333  812.866667  942.00
# Prvt    673.250000  848.132500  940.75
# Pub     690.600000  867.820000  935.00

# %%
dfp.index
# Out:
# Index(['Gov', 'Prvt', 'Pub'], dtype='object', name='Sector')

# %%
dfp.columns
# Out:
# Index(['Exp', 'Rev', 'Vol'], dtype='object')

# %%
dfp = pd.pivot_table(df1, index=['Sector','GST'], values=['Vol','Exp','Rev'])
dfp
# Out:
#                         Exp         Rev    Vol
# Sector GST
# Gov    Services  657.333333  812.866667  942.0
# Prvt   Goods     731.500000  854.615000  955.5
#        Services  615.000000  841.650000  926.0
# Pub    Goods     727.666667  852.866667  930.0
#        Services  635.000000  890.250000  942.5

# %%
dfp.index

# %%
dfp = pd.pivot_table(df1, index=['Sector','GST'], values=['Vol','Exp','Rev'], aggfunc='mean')
dfp
# Out:
#                         Exp         Rev    Vol
# Sector GST
# Gov    Services  657.333333  812.866667  942.0
# Prvt   Goods     731.500000  854.615000  955.5
#        Services  615.000000  841.650000  926.0
# Pub    Goods     727.666667  852.866667  930.0
#        Services  635.000000  890.250000  942.5

# %%
dfp = pd.pivot_table(df1, index=['Sector','GST'], values=['Vol','Exp','Rev'], 
                     aggfunc=['mean','max','count'])
dfp
# Out:
#                        mean                     max             count
#                         Exp         Rev    Vol  Exp    Rev  Vol   Exp Rev Vol
# Sector GST
# Gov    Services  657.333333  812.866667  942.0  689  881.6  992     3   3   3
# Prvt   Goods     731.500000  854.615000  955.5  789  875.0  966     2   2   2
#        Services  615.000000  841.650000  926.0  615  843.5  931     2   2   2
# Pub    Goods     727.666667  852.866667  930.0  899  874.4  966     3   3   3
#        Services  635.000000  890.250000  942.5  665  917.0  954     2   2   2

# %%
dfp = pd.pivot_table(df1, index=['Sector','GST'], 
                     values=['Vol','Exp','Rev'], 
                     aggfunc=['min','max',np.sum])
dfp
# Out:
# C:\Users\Edunet Foundation\AppData\Local\Temp\ipykernel_42960\285240889.py:1: FutureWarning: The provided callable <function sum at 0x000001BE906B7EC0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   dfp = pd.pivot_table(df1, index=['Sector','GST'],
#                  min               max               sum
#                  Exp     Rev  Vol  Exp    Rev  Vol   Exp      Rev   Vol
# Sector GST
# Gov    Services  633  733.00  900  689  881.6  992  1972  2438.60  2826
# Prvt   Goods     674  834.23  945  789  875.0  966  1463  1709.23  1911
#        Services  615  839.80  921  615  843.5  931  1230  1683.30  1852
# Pub    Goods     608  821.00  899  899  874.4  966  2183  2558.60  2790
#        Services  605  863.50  931  665  917.0  954  1270  1780.50  1885

# %%
def maxmindiff(c):
    print(c)
    print(type(c))
    print()
    return c.max()-c.min()

# %%
dfp = pd.pivot_table(df1, index=['Sector','GST'], 
                     values=['Vol','Exp','Rev'], 
                     aggfunc=[np.min,'max',maxmindiff])
dfp
# Out:
# Bangalore_Systems    900
# Indi_Services        992
# Central_Services     934
# Name: Vol, dtype: int64
# <class 'pandas.core.series.Series'>
#
# Eastern_Estates        945
# Bangalore_Breweries    966
# Name: Vol, dtype: int64
# <class 'pandas.core.series.Series'>
#
# Deccan_Sporting    931
# NCR_Infra          921
# Name: Vol, dtype: int64
# <class 'pandas.core.series.Series'>
#
# Kolkata_FMCG         925
# Chennai_Chemicals    966
# Chennai_Shipping     899
# Name: Vol, dtype: int64
# <class 'pandas.core.series.Series'>
#
# NCR_Leagles       931
# Bombay_Finance    954
# Name: Vol, dtype: int64
# <class 'pandas.core.series.Series'>
#
# Bangalore_Systems    650
# Indi_Services        633
# Central_Services     689
# Name: Exp, dtype: int64
# <class 'pandas.core.series.Series'>
#
# Eastern_Estates        789
# Bangalore_Breweries    674
# Name: Exp, dtype: int64
# <class 'pandas.core.series.Series'>
#
# Deccan_Sporting    615
# NCR_Infra          615
# Name: Exp, dtype: int64
# ...

# %%
df1[(df1.Sector == 'Pub') & (df1.GST == 'Services')]['Vol']
# Out:
# NCR_Leagles       931
# Bombay_Finance    954
# Name: Vol, dtype: int64

# %%
dfp = pd.pivot_table(df1, index=['Sector','GST'], 
                     values='Vol', 
                     aggfunc=maxmindiff)
dfp

# %%
dfp = pd.pivot_table(df1, index=['Sector','GST'], 
                     values='Vol', 
                     aggfunc=lambda c: c.max()-c.min())
dfp

# %%
# what is the minimum revenue of pub companies in chennai
dfp = pd.pivot_table(df1, index='Sector',
                     columns='HQ',
                     values=['Vol','Rev'], 
                     aggfunc=['min','max'])
dfp

# %%
print(type(dfp))

# %% [markdown]
# # Groupby

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds1.csv')
df1
# Out:
#                      Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Kolkata_FMCG         925  874.40  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles          931  863.50  605    Pub    1935  NCR    0    NCRL
# Bangalore_Systems    900  881.60  650    Gov    1361  Blr    0    BSYS
# Chennai_Chemicals    966  863.20  608    Pub    1656  Che    1    CHEM
# Indi_Services        992  733.00  633    Gov   13023  NCR    0    INDI
# Chennai_Shipping     899  821.00  899    Pub     899  Che    1    SHIP
# Eastern_Estates      945  834.23  789   Prvt    1873  Kol    1    EEST
# Central_Services     934  824.00  689    Gov    1573  NCR    1    CSRV
# Deccan_Sporting      931  839.80  615   Prvt     154  Hyd    1    SPRT
# Bangalore_Breweries  966  875.00  674   Prvt     119  Blr    1    BREW
# Bombay_Finance       954  917.00  665    Pub    1443  Mum    0    BFIN
# NCR_Infra            921  843.50  615   Prvt    1635  NCR    0    NCIN
#
# ...

# %%
df1.Sector.value_counts()
# Out:
# Sector
# Pub     5
# Prvt    4
# Gov     3
# Name: count, dtype: int64

# %%
df1.Sector.value_counts()
# Out:
# Sector
# Pub     5
# Prvt    4
# Gov     3
# Name: count, dtype: int64

# %%
dfg = df1.groupby(by='Sector')
print(type(dfg))
print()
for item in dfg:
    print(item)
    print()
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>
#
# ('Gov',                    Vol    Rev  Exp Sector  EmpCnt   HQ  MNC StockID       GST  \
# Bangalore_Systems  900  881.6  650    Gov    1361  Blr    0    BSYS  Services
# Indi_Services      992  733.0  633    Gov   13023  NCR    0    INDI  Services
# Central_Services   934  824.0  689    Gov    1573  NCR    1    CSRV  Services
#
#                   Start Date Taxpaid
# Bangalore_Systems   Apr 1950  34.74$
# Indi_Services       Mar 1920     15$
# Central_Services    Jun 1974  20.25$  )
#
# ('Prvt',                      Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Eastern_Estates      945  834.23  789   Prvt    1873  Kol    1    EEST
# Deccan_Sporting      931  839.80  615   Prvt     154  Hyd    1    SPRT
# Bangalore_Breweries  966  875.00  674   Prvt     119  Blr    1    BREW
# NCR_Infra            921  843.50  615   Prvt    1635  NCR    0    NCIN
#
#                           GST Start Date Taxpaid
# ...

# %%
dfg = df1.groupby(by='Sector')  
list(dfg)[0][-1]
# Out:
#                    Vol    Rev  Exp Sector  EmpCnt   HQ  MNC StockID       GST  \
# Bangalore_Systems  900  881.6  650    Gov    1361  Blr    0    BSYS  Services
# Indi_Services      992  733.0  633    Gov   13023  NCR    0    INDI  Services
# Central_Services   934  824.0  689    Gov    1573  NCR    1    CSRV  Services
#
#                   Start Date Taxpaid
# Bangalore_Systems   Apr 1950  34.74$
# Indi_Services       Mar 1920     15$
# Central_Services    Jun 1974  20.25$

# %%
df1.groupby(by='Sector').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# ...

# %%
df1.groupby(by='Sector')['Vol'].mean()
# Out:
# Sector
# Gov     942.00
# Prvt    940.75
# Pub     935.00
# Name: Vol, dtype: float64

# %%
df1.groupby(by='Sector')[['Vol','Rev']].mean()
# Out:
#            Vol         Rev
# Sector
# Gov     942.00  812.866667
# Prvt    940.75  848.132500
# Pub     935.00  867.820000

# %%
df1.groupby(by='Sector')[['Vol','Rev']].agg(['mean','min'])
# Out:
#            Vol              Rev
#           mean  min        mean     min
# Sector
# Gov     942.00  900  812.866667  733.00
# Prvt    940.75  921  848.132500  834.23
# Pub     935.00  899  867.820000  821.00

# %%
df1.groupby(by=['Sector','GST'])[['Vol','Rev']].agg(['mean','min'])
# Out:
#                    Vol              Rev
#                   mean  min        mean     min
# Sector GST
# Gov    Services  942.0  900  812.866667  733.00
# Prvt   Goods     955.5  945  854.615000  834.23
#        Services  926.0  921  841.650000  839.80
# Pub    Goods     930.0  899  852.866667  821.00
#        Services  942.5  931  890.250000  863.50

# %% [markdown]
# # Map

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds1.csv')
df1
# Out:
#                      Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Kolkata_FMCG         925  874.40  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles          931  863.50  605    Pub    1935  NCR    0    NCRL
# Bangalore_Systems    900  881.60  650    Gov    1361  Blr    0    BSYS
# Chennai_Chemicals    966  863.20  608    Pub    1656  Che    1    CHEM
# Indi_Services        992  733.00  633    Gov   13023  NCR    0    INDI
# Chennai_Shipping     899  821.00  899    Pub     899  Che    1    SHIP
# Eastern_Estates      945  834.23  789   Prvt    1873  Kol    1    EEST
# Central_Services     934  824.00  689    Gov    1573  NCR    1    CSRV
# Deccan_Sporting      931  839.80  615   Prvt     154  Hyd    1    SPRT
# Bangalore_Breweries  966  875.00  674   Prvt     119  Blr    1    BREW
# Bombay_Finance       954  917.00  665    Pub    1443  Mum    0    BFIN
# NCR_Infra            921  843.50  615   Prvt    1635  NCR    0    NCIN
#
# ...

# %%
md1 = {'Kol':'EZ', 'Mum':'WZ','Che':'SZ','Blr':'SZ','NCR':'NZ'}

# %%
df1['Zone'] = df1.HQ.map(md1)
df1
# Out:
#                      Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Kolkata_FMCG         925  874.40  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles          931  863.50  605    Pub    1935  NCR    0    NCRL
# Bangalore_Systems    900  881.60  650    Gov    1361  Blr    0    BSYS
# Chennai_Chemicals    966  863.20  608    Pub    1656  Che    1    CHEM
# Indi_Services        992  733.00  633    Gov   13023  NCR    0    INDI
# Chennai_Shipping     899  821.00  899    Pub     899  Che    1    SHIP
# Eastern_Estates      945  834.23  789   Prvt    1873  Kol    1    EEST
# Central_Services     934  824.00  689    Gov    1573  NCR    1    CSRV
# Deccan_Sporting      931  839.80  615   Prvt     154  Hyd    1    SPRT
# Bangalore_Breweries  966  875.00  674   Prvt     119  Blr    1    BREW
# Bombay_Finance       954  917.00  665    Pub    1443  Mum    0    BFIN
# NCR_Infra            921  843.50  615   Prvt    1635  NCR    0    NCIN
#
# ...

# %% [raw]
# Sales_Performance
#
# vol>935: 'Excellent_Sales
# vol < 910 'Average_Sales'
# 'Good_Sales'

# %%
def sales_query(sales_value):
    if sales_value > 955:
        return 'Excellent'
    elif sales_value < 910:
        return 'Average'
    else:
        return 'Good'

# %%
df1['Sales_Performance'] = df1.Vol.map(sales_query)
df1

# %% [markdown]
# # Stack & Unstack

# %% [raw]
#                       2021  2021   2022   2022
#                        Q1   Q2      Q1    Q2
#
#
# Tata     FMCG
# Tata     Tech
# Birla    FMCG
# Birla    Tech
# Wipro    FMCG
# Wipro    Tech
# ITC      FMCG
# ITC      Tech
# Reliance FMCG
# Reliane  Tech

# %%
col_level0 = [2021,2022]
col_level1 = ['Q1', 'Q2']
col_labels= pd.MultiIndex.from_product([col_level0, col_level1])

row_level0 = ['Tata','Birla','Wipro','ITC','Reliance']
row_level1 = ['FMCG', 'Tech']
row_labels= pd.MultiIndex.from_product([row_level0, row_level1])

np.random.seed(23)
n10x4 = np.random.randint(low=10, high=100,size=(10,4))

# %%
df1 = pd.DataFrame(n10x4, index=row_labels, columns=col_labels)
df1

# %%
df1.index

# %%
df1.columns

# %%
df1.loc[(   'Wipro', 'Tech'),(2022, 'Q1') ]

# %%
df2 = df1.stack()
print(df2.index)
print(df2.columns)

# %%
df2 = df1.unstack()
print(df2.index)
print(df2.columns)
df2

# %%
df1

# %%
df1.unstack(level=0).stack(level=-2).unstack(level=0).stack(level=-1).stack(level=0).unstack(level=-1)

# %%
df1.stack(level=-1).unstack(level=0).stack(level=-1).unstack(level=-1)

# %%
df1.stack(level=-1).unstack(level=0).unstack(level=0).stack(level=-1).stack(level=0).unstack(level=-1)

# %% [markdown]
# # Melting

# %%
df31 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds31.csv')
df31
# Out:
#     Location Temperature  Jan2019  Feb2019  Mar2019
# 0  Bangalore     Predict       23       25       28
# 1    Chennai      Actual       32       34       36

# %%
pd.melt(df31, id_vars=['Location', 'Temperature'])
# Out:
#     Location Temperature variable  value
# 0  Bangalore     Predict  Jan2019     23
# 1    Chennai      Actual  Jan2019     32
# 2  Bangalore     Predict  Feb2019     25
# 3    Chennai      Actual  Feb2019     34
# 4  Bangalore     Predict  Mar2019     28
# 5    Chennai      Actual  Mar2019     36

# %%
pd.melt(df31, id_vars=['Location', 'Temperature'],
        value_name='melted_cols_values')

# %%
dfm  = pd.melt(df31, id_vars=['Location', 'Temperature'], 
        var_name = 'melted_cols_names',value_name='melted_cols_values')

# %%
dfm
# Out:
#     Location Temperature melted_cols_names  melted_cols_values
# 0  Bangalore     Predict           Jan2019                  23
# 1    Chennai      Actual           Jan2019                  32
# 2  Bangalore     Predict           Feb2019                  25
# 3    Chennai      Actual           Feb2019                  34
# 4  Bangalore     Predict           Mar2019                  28
# 5    Chennai      Actual           Mar2019                  36

# %% [markdown]
# # NaN Handling

# %%
df0 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds0.csv')
df0

# %%
df0.isna().sum().sum()

# %%
df0.info()

# %%
df0.isna().sum()

# %%
df0.dropna()

# %%
df0.Rev.fillna(850)

# %%
df0.Rev.mean()

# %%
df0.Rev.fillna(df0.Rev.mean(), inplace=True)

# %%
df0.EmpCnt.mean()

# %%
df0.EmpCnt.median()

# %%
df0.EmpCnt.fillna(df0.EmpCnt.median(), inplace=True)

# %%
df0.Sector.fillna(method='bfill')

# %%
df0.Sector.fillna(method='ffill')

# %% [markdown]
# # Drop

# %%
df0 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds0.csv')
df0

# %%
df0.drop(columns=['Vol','Exp','HQ'],  
         index=['NCR_Leagles','Bombay_Finance'],
        inplace=True)
df0

# %% [markdown]
# # Drop Duplicates

# %%
df33 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds33.csv')
df33
# Out:
#         Date    City  Temperature  Humidity
# 0  15/1/2019  Shimla           11        67
# 1  15/2/2019  Shimla           12        65
# 2  15/3/2019  Shimla           11        57
# 3  15/1/2019  Shimla           11        67
# 4  15/1/2019    Pune           29        34
# 5  15/2/2019    Pune           32        26
# 6  15/1/2020    Pune           29        21
# 7  15/1/2019  Mysore           28        49
# 8  15/2/2019  Mysore           31        47
# 9  15/1/2020  Mysore           33        49

# %%
df33.duplicated(subset=None, keep='first')
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
df33.duplicated(subset=None, keep='last')
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
df33.duplicated(subset=None, keep=False)
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
df33.duplicated(subset=['City','Temperature'], keep='first')
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
df33[df33.duplicated(subset=['City','Temperature'], keep='first')]

# %%
print(df33)
df33.drop_duplicates(subset=['City','Temperature'], keep='first')
# Out:
#         Date    City  Temperature  Humidity
# 0  15/1/2019  Shimla           11        67
# 1  15/2/2019  Shimla           12        65
# 2  15/3/2019  Shimla           11        57
# 3  15/1/2019  Shimla           11        67
# 4  15/1/2019    Pune           29        34
# 5  15/2/2019    Pune           32        26
# 6  15/1/2020    Pune           29        21
# 7  15/1/2019  Mysore           28        49
# 8  15/2/2019  Mysore           31        47
# 9  15/1/2020  Mysore           33        49
#         Date    City  Temperature  Humidity
# 0  15/1/2019  Shimla           11        67
# 1  15/2/2019  Shimla           12        65
# 4  15/1/2019    Pune           29        34
# 5  15/2/2019    Pune           32        26
# 7  15/1/2019  Mysore           28        49
# 8  15/2/2019  Mysore           31        47
# 9  15/1/2020  Mysore           33        49

# %%
print(df33)
df33.drop_duplicates(subset=['City','Temperature'], keep='last')

# %%
print(df33)
df33.drop_duplicates(subset=['City','Temperature'], keep=False)

# %% [markdown]
# # Replace

# %%
df33 = pd.read_csv('https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds33.csv')
df33

# %%
df33.replace({'Pune':'Mumbai'})

# %%
df33.City.replace({'Pune':'Nagpur'})
